# %%
import pandas as pd

# %% [markdown]
# # Recommender System:
#
# - The last thing to do is to use our saved models to recommend items to users:

# %% [markdown]
# ### For the requested user:
# - Calculate the score for every item.
# - Sort the items based on the score and output the top results.

# %% [markdown]
# ### Check which users exist on the test set

# %%
import pickle
import pandas as pd
import numpy as np

import os

#Keras
from keras.models import load_model
from keras import backend as K

# Tensorflow
import tensorflow as tf

from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %% [markdown]
# ### Set and Check GPUs

# %%
def set_check_gpu():
    cfg = K.tf.ConfigProto()
    cfg.gpu_options.per_process_gpu_memory_fraction =1 # allow all of the GPU memory to be allocated
    # for 8 GPUs
    # cfg.gpu_options.visible_device_list = "0,1,2,3,4,5,6,7" # "0,1"
    # for 1 GPU
    cfg.gpu_options.visible_device_list = "0"
    #cfg.gpu_options.allow_growth = True  # # Don't pre-allocate memory; dynamically allocate the memory used on the GPU as-needed
    #cfg.log_device_placement = True  # to log device placement (on which device the operation ran)
    sess = K.tf.Session(config=cfg)
    K.set_session(sess)  # set this TensorFlow session as the default session for Keras

    print("* TF version: ", [tf.__version__, tf.test.is_gpu_available()])
    print("* List of GPU(s): ", tf.config.experimental.list_physical_devices() )
    print("* Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) 
  
    
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";
    # set for 8 GPUs
#     os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3,4,5,6,7";
    # set for 1 GPU
    os.environ["CUDA_VISIBLE_DEVICES"] = "0";

    # Tf debugging option
    tf.debugging.set_log_device_placement(True)

    gpus = tf.config.experimental.list_physical_devices('GPU')

    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)

#     print(tf.config.list_logical_devices('GPU'))
    print(tf.config.experimental.list_physical_devices('GPU'))
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
set_check_gpu()
# Out:
# * TF version:  ['1.15.2', True]
# * List of GPU(s):  [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'), PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# * Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
all_info = pd.read_parquet("./data/Cleaned_meta_Clothing_Shoes_and_Jewelry.parquet")
ratings_test = pd.read_parquet('./data/ratings_test.parquet')
ratings_train = pd.read_parquet('./data/ratings_train.parquet')

# %%
ratings_test.user_id.value_counts().sort_values(ascending=False).head(10)
# Out:
# 635       28
# 33102     26
# 1123      25
# 136939    24
# 7401      23
# 136131    22
# 5768      20
# 34951     20
# 52789     20
# 4959      20
# Name: user_id, dtype: int64

# %% [markdown]
# ### ** Create a  recommendation example dataset of 100 users from the test set and 100 random items for each and predict recommendations for them

# %%
items = all_info.asin.unique()
item_map = {i:val for i,val in enumerate(items)}
inverse_item_map = {val:i for i,val in enumerate(items)}
all_info["old_item_id"] = all_info["asin"] # copying for join with metadata
all_info["item_id"] = all_info["asin"].map(inverse_item_map)
items = all_info.item_id.unique()
print ("We have %d unique items in metadata "%items.shape[0])
# Out:
# We have 2681355 unique items in metadata

# %%
all_info['description'] = all_info['description'].fillna(all_info['title'].fillna('no_data'))
all_info['title'] = all_info['title'].fillna(all_info['description'].fillna('no_data').apply(str).str[:20])
all_info['image'] = all_info['image'].fillna('no_data')
all_info['price'] = pd.to_numeric(all_info['price'],errors="coerce")
all_info['price'] = all_info['price'].fillna(all_info['price'].median())

# %%
# creating metadata mappings 
titles = all_info['title'].unique()
titles_map = {i:val for i,val in enumerate(titles)}
inverse_titles_map = {val:i for i,val in enumerate(titles)}

price = all_info['price'].unique()
price_map = {i:val for i,val in enumerate(price)}
inverse_price_map = {val:i for i,val in enumerate(price)}

print ("We have %d prices" %price.shape)
print ("We have %d titles" %titles.shape)


all_info['price_id'] = all_info['price'].map(inverse_price_map)
all_info['title_id'] = all_info['title'].map(inverse_titles_map)

# creating dict from 
item2prices = {}
for val in all_info[['item_id','price_id']].dropna().drop_duplicates().iterrows():
    item2prices[val[1]["item_id"]] = val[1]["price_id"]

item2titles = {}
for val in all_info[['item_id','title_id']].dropna().drop_duplicates().iterrows():
    item2titles[val[1]["item_id"]] = val[1]["title_id"]
        


# populating the rating dataset with item metadata info
ratings_train["price_id"] = ratings_train["item_id"].map(lambda x : item2prices[x])
ratings_train["title_id"] = ratings_train["item_id"].map(lambda x : item2titles[x])


# populating the test dataset with item metadata info
ratings_test["price_id"] = ratings_test["item_id"].map(lambda x : item2prices[x])
ratings_test["title_id"] = ratings_test["item_id"].map(lambda x : item2titles[x])
# Out:
# We have 1 prices
# We have 2507255 titles

# %%
# ratings_test = pd.read_parquet('./data/ratings_test.parquet')
# ratings_train = pd.read_parquet('./data/ratings_train.parquet')

# %%
items = all_info.item_id.unique()
df_items = pd.DataFrame(data=items.flatten(),columns=['item_id'])
df_items = pd.merge(df_items,all_info,how='left',left_on=('item_id'),right_on=('item_id'))
df_items= df_items.sample(100)
df_items['key'] = 1
print ("We have %d unique items  "%df_items['item_id'].shape[0])
# df_items= df_items[['item_id', 'description', 'category', 'title', 'title_id', 'price', 'price_id', 'brand', 'key']]
df_items= df_items[['item_id', 'description', 'category', 'title', 'title_id', 'price', 'price_id', 'key']]
print(df_items.shape)
df_items.head(2)
# Out:
# We have 100 unique items
# (100, 8)
#          item_id                                        description  \
# 923406    919702  Aokin Sexy Ladies Women Push up Padded Bikini ...
# 1092135  1088431  Baby Phat Women's Chance Round Toe Platform Pu...
#
#                                                   category  \
# 923406   [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 1092135   [Clothing, Shoes & Jewelry, Women, Shoes, Pumps]
#
#                                                      title  title_id  price  \
# 923406   Aokin Sexy Ladies Women Push up Padded Bikini ...    871016    NaN
# 1092135  Baby Phat Women's Chance Round Toe Platform Pu...   1029726    NaN
#
#          price_id  key
# 923406          0    1
# 1092135         0    1

# %%
users = ratings_test.user_id.unique()
df_users = pd.DataFrame(data=users.flatten(),columns=['user_id'])
df_users = pd.merge(df_users,ratings_test,how='left',left_on=('user_id'),right_on=('user_id'))
df_users= df_users.sample(100)
df_users['key'] = 1
print ("We have %d unique users  "%df_users['user_id'].shape[0])
df_users= df_users[['user_id', 'user_name', 'key']]
print(df_users.shape)
df_users.head(2)
# Out:
# We have 100 unique users
# (100, 3)
#         user_id        user_name  key
# 2644       5053         michelle    1
# 171483   297377  Amazon Customer    1

# %% [markdown]
# ## Merge users and item and items metadata

# %%
df_unseenData= pd.merge(df_users, df_items, on='key')
del df_unseenData['key']
print ("We have %d unique records in the recommendation example dataset "%df_unseenData.shape[0])
print(df_unseenData.shape)
df_unseenData.sample(10)
# Out:
# We have 10000 unique records in the recommendation example dataset
# (10000, 9)
#       user_id        user_name  item_id  \
# 7251    86155    M. Lee Taylor    33378
# 4520   163736   Chris Uppercut  1226645
# 7984    36849           Andy L  2410280
# 1158   327960     Mommytsunami   190572
# 3052    62758            Ian C  1198015
# 107    297377  Amazon Customer   789144
# 3560   257633      HappyMama89    39301
# 6931    67469            Alana    76856
# 3767    44308        Rachel N.   903763
# 1861   472996            Terry   418294
#
#                                             description  \
# 7251  [From the Phantom of the Opera Collection. Pha...
# 4520  [A beautiful handbag with a grey blue color tone]
# 7984  Gerber Onesies Baby Boy Sleep N' Play Sleepers...
# 1158  [This fashionable and lightweight purse hooks ...
# 3052  [100% polyester jersey knit; heat transfer lab...
# 107   [In 1920 Sbicca Shoes was launched by Frank an...
# 3560  [These Bates 1728 Women's 8-Inch DuraShocks St...
# 6931  [A classic polo crafted of soft pima cotton. A...
# 3767  [, The Amazon Curated Collection, Discover the...
# 1861  [, The Amazon Curated Collection, Discover the...
#
#                                                category  \
# 7251  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...
# 4520  [Clothing, Shoes & Jewelry, Women, Handbags & ...
# 7984                  [Clothing, Shoes & Jewelry, Baby]
# 1158  [Clothing, Shoes & Jewelry, Women, Accessories...
# 3052  [Clothing, Shoes & Jewelry, Men, Clothing, Act...
# 107   [Clothing, Shoes & Jewelry, Women, Shoes, Sand...
# 3560  [Clothing, Shoes & Jewelry, Women, Uniforms, W...
# 6931  [Clothing, Shoes & Jewelry, Men, Clothing, Shi...
# 3767  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...
# 1861  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
#
#                                                   title  title_id  price  \
# 7251  Fun To Collect Phantom of the Opera Phantom Ma...     31655    NaN
# 4520  Lauren Ferretti Women's - Fashion Grey Shoulde...   1158125    NaN
# 7984  Gerber Onesies Baby Boy Sleep N' Play Sleepers...   2254698    NaN
# 1158     Pink Diamond Folding Handbag Purse Hook Hanger    181318    NaN
# 3052            Gildan G420 Performance 4.5 oz. T-Shirt    722013    NaN
# 107                               Sbicca Women's Kismet    747991    NaN
# 3560         Bates Women's 8" Durashocks Steel Toe Boot     37173    NaN
# 6931              Nautica Men's SS Clarkson Stripe Polo     72720    NaN
# 3767  Sterling Silver Genuine White Topaz and Blue S...    856256    NaN
# 1861  Sterling Silver Quartz Floral 9mm Freshwater C...    397678    NaN
#
#       price_id
# 7251         0
# 4520         0
# 7984         0
# 1158         0
# 3052         0
# 107          0
# 3560         0
# 6931         0
# 3767         0
# 1861         0

# %%
df_unseenData.columns
# Out:
# Index(['user_id', 'user_name', 'item_id', 'description', 'category', 'title',
#        'title_id', 'price', 'price_id'],
#       dtype='object')

# %%
from os import listdir
from os.path import isfile, join

mypath = './models'

onlyfiles = [f.replace('.h5', '') for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles
# Out:
# ['dense_2_Concatenate_10_embeddings_10_epochs',
#  'dense_1_Multiply_50_embeddings_7_epochs',
#  'dense_2_Concatenate_20_embeddings_25_epochs',
#  'dense_1_Multiply_50_embeddings_4_epochs_dropout',
#  'dense_2_Meta_Concatenate_15_embeddings_50_epochs-DropOut0.6',
#  'matrix_facto_10_embeddings_3_epochs',
#  'dense_1_Multiply_50_embeddings_20_epochs_dropout',
#  'dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.6-dropout-input',
#  'dense_1_Multiply_50_embeddings_7_epochs_dropout',
#  'dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.8',
#  'matrix_facto_10_embeddings_100_epochs',
#  'dense_2_Meta_Concatenate_15_embeddings_30_epochs-DropOut0.6',
#  'matrix_facto_10_embeddings_20_epochs',
#  'dense_4_Multiply_5_embeddings_7_epochs',
#  'dense_1_Multiply_50_embeddings_2_epochs_dropout']

# %% [markdown]
# ## Predict the ratings for the items and users in the a recommendation example dataset:

# %%
load_path = "./models/"

models =['dense_2_Concatenate_10_embeddings_10_epochs',
 'dense_1_Multiply_50_embeddings_7_epochs',
 'dense_2_Concatenate_20_embeddings_25_epochs',
 'dense_1_Multiply_50_embeddings_4_epochs_dropout',
 'matrix_facto_10_embeddings_3_epochs',
 'dense_1_Multiply_50_embeddings_20_epochs_dropout',
 'dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.6-dropout-input',
 'dense_1_Multiply_50_embeddings_7_epochs_dropout',
 'dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.8',
 'matrix_facto_10_embeddings_100_epochs',
 'matrix_facto_10_embeddings_20_epochs',
 'dense_4_Multiply_5_embeddings_7_epochs',
 'dense_1_Multiply_50_embeddings_2_epochs_dropout']

models_meta = [
 'dense_2_Meta_Concatenate_15_embeddings_50_epochs-DropOut0.6',
 'dense_2_Meta_Concatenate_15_embeddings_30_epochs-DropOut0.6',
]

# for mod in models:
#     model = load_model(load_path+mod+'.h5')
#     df_unseenData['preds_' + mod] = model.predict([df_unseenData['user_id'],
#                                                    df_unseenData['item_id'],
#                                                    df_unseenData['price_id'],
#                                                    df_unseenData['title_id']])

for mod in models:
    model = load_model(load_path+mod+'.h5')
    df_unseenData['preds_' + mod] = model.predict([df_unseenData['user_id'],
                                                   df_unseenData['item_id']])


df_unseenData.head(2)
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#    user_id user_name  item_id  \
# 0     5053  michelle   919702
# 1     5053  michelle  1088431
#
#                                          description  \
# 0  Aokin Sexy Ladies Women Push up Padded Bikini ...
# 1  Baby Phat Women's Chance Round Toe Platform Pu...
#
#                                             category  \
# 0  [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 1   [Clothing, Shoes & Jewelry, Women, Shoes, Pumps]
#
#                                                title  title_id  price  \
# 0  Aokin Sexy Ladies Women Push up Padded Bikini ...    871016    NaN
# 1  Baby Phat Women's Chance Round Toe Platform Pu...   1029726    NaN
#
#    price_id  preds_dense_2_Concatenate_10_embeddings_10_epochs  ...  \
# 0         0                                           4.014494  ...
# 1         0                                           4.014494  ...
#
#    preds_dense_1_Multiply_50_embeddings_4_epochs_dropout  \
# 0                                           4.141841
# 1                                           4.141841
#
#    preds_matrix_facto_10_embeddings_3_epochs  \
# 0                                        0.0
# 1                                        0.0
#
#    preds_dense_1_Multiply_50_embeddings_20_epochs_dropout  \
# 0                                           4.311826
# 1                                           4.311826
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.6-dropout-input  \
# 0                                           3.961529
# 1                                           3.961529
#
#    preds_dense_1_Multiply_50_embeddings_7_epochs_dropout  \
# 0                                           3.757429
# 1                                           3.757429
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.8  \
# 0                                           3.848483
# 1                                           3.848483
#
#    preds_matrix_facto_10_embeddings_100_epochs  \
# 0                                          0.0
# 1                                          0.0
#
#    preds_matrix_facto_10_embeddings_20_epochs  \
# 0                                         0.0
# 1                                         0.0
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs  \
# 0                                      4.292699
# 1                                      4.292699
#
#    preds_dense_1_Multiply_50_embeddings_2_epochs_dropout
# 0                                           3.905577
# 1                                           3.905577
#
# [2 rows x 22 columns]

# %%
df_unseenData['user_id'].head(n=2)
# Out:
# 0    5053
# 1    5053
# Name: user_id, dtype: int64

# %%
df_unseenData.columns
# Out:
# Index(['user_id', 'user_name', 'item_id', 'description', 'category', 'title',
#        'title_id', 'price', 'price_id',
#        'preds_dense_2_Concatenate_10_embeddings_10_epochs',
#        'preds_dense_1_Multiply_50_embeddings_7_epochs',
#        'preds_dense_2_Concatenate_20_embeddings_25_epochs',
#        'preds_dense_1_Multiply_50_embeddings_4_epochs_dropout',
#        'preds_matrix_facto_10_embeddings_3_epochs',
#        'preds_dense_1_Multiply_50_embeddings_20_epochs_dropout',
#        'preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.6-dropout-input',
#        'preds_dense_1_Multiply_50_embeddings_7_epochs_dropout',
#        'preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.8',
#        'preds_matrix_facto_10_embeddings_100_epochs',
#        'preds_matrix_facto_10_embeddings_20_epochs',
#        'preds_dense_4_Multiply_5_embeddings_7_epochs',
#        'preds_dense_1_Multiply_50_embeddings_2_epochs_dropout'],
#       dtype='object')

# %% [markdown]
# ## Check which users exist on the example set

# %%
df_unseenData.user_id.value_counts().sort_values(ascending=False).head(5)
df_unseenData[['user_id','preds_dense_1_Multiply_50_embeddings_7_epochs']].sort_values('preds_dense_1_Multiply_50_embeddings_7_epochs',ascending=True).head(5)
# Out:
#       user_id  preds_dense_1_Multiply_50_embeddings_7_epochs
# 8128    36754                                       1.930570
# 3528   257633                                       2.270640
# 7528    70795                                       2.393019
# 1728    49526                                       2.499284
# 7028    50398                                       2.512622

# %% [markdown]
# ## A function that will return recommendation list for a given user

# %%
df_unseenData.head(n=3)
# Out:
#    user_id user_name  item_id  \
# 0     5053  michelle   919702
# 1     5053  michelle  1088431
# 2     5053  michelle   370649
#
#                                          description  \
# 0  Aokin Sexy Ladies Women Push up Padded Bikini ...
# 1  Baby Phat Women's Chance Round Toe Platform Pu...
# 2          [NIKE FLYKNIT RACER - 'OREO' -526628-012]
#
#                                             category  \
# 0  [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 1   [Clothing, Shoes & Jewelry, Women, Shoes, Pumps]
# 2  [Clothing, Shoes & Jewelry, Men, Shoes, Athlet...
#
#                                                title  title_id  price  \
# 0  Aokin Sexy Ladies Women Push up Padded Bikini ...    871016    NaN
# 1  Baby Phat Women's Chance Round Toe Platform Pu...   1029726    NaN
# 2  NIKE Flyknit Racer - 'Oreo' -526628-012 Black,...    353019    NaN
#
#    price_id  preds_dense_2_Concatenate_10_embeddings_10_epochs  ...  \
# 0         0                                           4.014494  ...
# 1         0                                           4.014494  ...
# 2         0                                           4.014494  ...
#
#    preds_dense_1_Multiply_50_embeddings_4_epochs_dropout  \
# 0                                           4.141841
# 1                                           4.141841
# 2                                           4.141841
#
#    preds_matrix_facto_10_embeddings_3_epochs  \
# 0                                        0.0
# 1                                        0.0
# 2                                        0.0
#
#    preds_dense_1_Multiply_50_embeddings_20_epochs_dropout  \
# 0                                           4.311826
# 1                                           4.311826
# 2                                           4.311826
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.6-dropout-input  \
# 0                                           3.961529
# 1                                           3.961529
# 2                                           3.961529
#
#    preds_dense_1_Multiply_50_embeddings_7_epochs_dropout  \
# 0                                           3.757429
# 1                                           3.757429
# 2                                           3.757429
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs-DropOut-0.8  \
# 0                                           3.848483
# 1                                           3.848483
# 2                                           3.848483
#
#    preds_matrix_facto_10_embeddings_100_epochs  \
# 0                                          0.0
# 1                                          0.0
# 2                                          0.0
#
#    preds_matrix_facto_10_embeddings_20_epochs  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.0
#
#    preds_dense_4_Multiply_5_embeddings_7_epochs  \
# 0                                      4.292699
# 1                                      4.292699
# 2                                      4.292699
#
#    preds_dense_1_Multiply_50_embeddings_2_epochs_dropout
# 0                                           3.905577
# 1                                           3.905577
# 2                                           3.905577
#
# [3 rows x 22 columns]

# %%
load_path = "./models/"

def get_recommendations(userID , model_scr, df_Data):
    if userID not in df_Data['user_id'].values:
        print("\nUser ID not found %d" %userID)
        return userID
       
    print("\nRecommendations for user id %d Name: %s is:" % (userID, df_Data.loc[df_Data['user_id'] == userID, 'user_name'].values[0]))
   
    df_output=df_Data.loc[df_Data['user_id'] == userID][['item_id','title','description','category','price', model_scr,    
     ]].sort_values(model_scr,ascending=False).set_index('item_id')
#     print(df_output)
    
    df_output.rename(columns={model_scr: 'score'}, inplace=True)
    
    #add ASIN form item_id
    df_output['asin'] = df_Data['item_id'].apply(item_map)
    
    return df_output

# %% [markdown]
# ### Recommend items to a given user
#
# - Using dense_1_Multiply_50_embeddings_7_epochs

# %%
#######  User ID: 36754                       
df_output = get_recommendations(userID=36754 ,model_scr='preds_dense_1_Multiply_50_embeddings_7_epochs', df_Data=df_unseenData)
df_output.head(10)
# Out:
# Recommendations for user id 36754 Name: MGH is:
#                                                      title  \
# item_id
# 76856                Nautica Men's SS Clarkson Stripe Polo
# 127697   Santa Suit - Men's 8 piece Santa Costume (XL (...
# 33378    Fun To Collect Phantom of the Opera Phantom Ma...
# 190572      Pink Diamond Folding Handbag Purse Hook Hanger
# 75478    Caravelle by Bulova Men's 44D002 Diamond Accen...
# 39301           Bates Women's 8" Durashocks Steel Toe Boot
# 242039   Light Blue Sparkle Captive Ring Eyebrow Tragus...
# 42351    14k White Gold Pear Shaped Aquamarine and Diam...
# 241891   Black 3mm 14G Internally Threaded Replacement ...
# 85350                  Lovely People Women's Kimberly Flat
#
#                                                description  \
# item_id
# 76856    [A classic polo crafted of soft pima cotton. A...
# 127697   [This Santa Suit has it all! It includes the P...
# 33378    [From the Phantom of the Opera Collection. Pha...
# 190572   [This fashionable and lightweight purse hooks ...
# 75478    [In 1875, a young Czech immigrant named Joseph...
# 39301    [These Bates 1728 Women's 8-Inch DuraShocks St...
# 242039   Light Blue Sparkle Captive Ring Eyebrow Tragus...
# 42351    14k White Gold Pear Shaped Aquamarine and Diam...
# 241891   Black 3mm 14G Internally Threaded Replacement ...
# 85350    [Shoes for Lovely People was created by appare...
#
#                                                   category  price     score
# item_id
# 76856    [Clothing, Shoes & Jewelry, Men, Clothing, Shi...    NaN  3.157357
# 127697   [Clothing, Shoes & Jewelry, Costumes & Accesso...    NaN  3.059101
# 33378    [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...    NaN  3.011844
# 190572   [Clothing, Shoes & Jewelry, Women, Accessories...    NaN  2.936568
# 75478    [Clothing, Shoes & Jewelry, Men, Watches, Wris...    NaN  2.893246
# 39301    [Clothing, Shoes & Jewelry, Women, Uniforms, W...    NaN  2.785911
# 242039   [Clothing, Shoes & Jewelry, Women, Jewelry, Bo...    NaN  2.775016
# 42351    [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...    NaN  2.754715
# 241891   [Clothing, Shoes & Jewelry, Women, Jewelry, Bo...    NaN  2.749818
# 85350    [Clothing, Shoes & Jewelry, Women, Shoes, Flat...    NaN  2.740991

# %% [markdown]
# ## Make predictions for another user using another model:

# %%
#######  User ID

user_id = 257633
df_output = get_recommendations(userID=user_id ,model_scr='preds_dense_1_Multiply_50_embeddings_7_epochs',df_Data=df_unseenData)
df_output.head(10)
# Out:
# Recommendations for user id 257633 Name: HappyMama89 is:
#                                                      title  \
# item_id
# 76856                Nautica Men's SS Clarkson Stripe Polo
# 127697   Santa Suit - Men's 8 piece Santa Costume (XL (...
# 33378    Fun To Collect Phantom of the Opera Phantom Ma...
# 190572      Pink Diamond Folding Handbag Purse Hook Hanger
# 75478    Caravelle by Bulova Men's 44D002 Diamond Accen...
# 39301           Bates Women's 8" Durashocks Steel Toe Boot
# 42351    14k White Gold Pear Shaped Aquamarine and Diam...
# 105850                  Leg Avenue Women's Comic Book Hero
# 85350                  Lovely People Women's Kimberly Flat
# 242039   Light Blue Sparkle Captive Ring Eyebrow Tragus...
#
#                                                description  \
# item_id
# 76856    [A classic polo crafted of soft pima cotton. A...
# 127697   [This Santa Suit has it all! It includes the P...
# 33378    [From the Phantom of the Opera Collection. Pha...
# 190572   [This fashionable and lightweight purse hooks ...
# 75478    [In 1875, a young Czech immigrant named Joseph...
# 39301    [These Bates 1728 Women's 8-Inch DuraShocks St...
# 42351    14k White Gold Pear Shaped Aquamarine and Diam...
# 105850   [3 piece comic book hero, includes halter cat ...
# 85350    [Shoes for Lovely People was created by appare...
# 242039   Light Blue Sparkle Captive Ring Eyebrow Tragus...
#
#                                                   category  price     score
# item_id
# 76856    [Clothing, Shoes & Jewelry, Men, Clothing, Shi...    NaN  3.406863
# 127697   [Clothing, Shoes & Jewelry, Costumes & Accesso...    NaN  3.380237
# 33378    [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...    NaN  3.332020
# 190572   [Clothing, Shoes & Jewelry, Women, Accessories...    NaN  3.309201
# 75478    [Clothing, Shoes & Jewelry, Men, Watches, Wris...    NaN  3.287312
# 39301    [Clothing, Shoes & Jewelry, Women, Uniforms, W...    NaN  3.249515
# 42351    [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...    NaN  3.223683
# 105850   [Clothing, Shoes & Jewelry, Costumes & Accesso...    NaN  3.221000
# 85350    [Clothing, Shoes & Jewelry, Women, Shoes, Flat...    NaN  3.213484
# 242039   [Clothing, Shoes & Jewelry, Women, Jewelry, Bo...    NaN  3.213298

# %%
df_output = df_output.reset_index()
df_output['user_id'] = user_id
df_output['asin'] = df_output['item_id'].apply(lambda x : item_map[x])
df_output['url'] = df_output['item_id'].apply(lambda x : 'https://www.amazon.com/dp/'+item_map[x])
df_output = df_output[['user_id','item_id', 'score', 'asin', 'url', 'title', 'description', 'category', 'price']]

# %%
df_output.head()
# Out:
#    user_id  item_id     score        asin  \
# 0   257633    76856  3.406863  B00139CLCC
# 1   257633   127697  3.380237  B001LQRDMA
# 2   257633    33378  3.332020  B000K4SVCA
# 3   257633   190572  3.309201  B002UZ1UW0
# 4   257633    75478  3.287312  B0012XSW68
#
#                                     url  \
# 0  https://www.amazon.com/dp/B00139CLCC
# 1  https://www.amazon.com/dp/B001LQRDMA
# 2  https://www.amazon.com/dp/B000K4SVCA
# 3  https://www.amazon.com/dp/B002UZ1UW0
# 4  https://www.amazon.com/dp/B0012XSW68
#
#                                                title  \
# 0              Nautica Men's SS Clarkson Stripe Polo
# 1  Santa Suit - Men's 8 piece Santa Costume (XL (...
# 2  Fun To Collect Phantom of the Opera Phantom Ma...
# 3     Pink Diamond Folding Handbag Purse Hook Hanger
# 4  Caravelle by Bulova Men's 44D002 Diamond Accen...
#
#                                          description  \
# 0  [A classic polo crafted of soft pima cotton. A...
# 1  [This Santa Suit has it all! It includes the P...
# 2  [From the Phantom of the Opera Collection. Pha...
# 3  [This fashionable and lightweight purse hooks ...
# 4  [In 1875, a young Czech immigrant named Joseph...
#
#                                             category  price
# 0  [Clothing, Shoes & Jewelry, Men, Clothing, Shi...    NaN
# 1  [Clothing, Shoes & Jewelry, Costumes & Accesso...    NaN
# 2  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...    NaN
# 3  [Clothing, Shoes & Jewelry, Women, Accessories...    NaN
# 4  [Clothing, Shoes & Jewelry, Men, Watches, Wris...    NaN

# %% [markdown]
# ### select 100 users from unseen data

# %%
all_predicted_df = pd.DataFrame()

for user_id in df_unseenData.sample(n=100, random_state=0)['user_id']:
    print("selected 100 user_id:", user_id)
    df_output = get_recommendations(userID=user_id ,model_scr='preds_dense_1_Multiply_50_embeddings_7_epochs',df_Data=df_unseenData)
    df_output = df_output.reset_index()
    df_output['user_id'] = user_id
    df_output['asin'] = df_output['item_id'].apply(lambda x : item_map[x])
    df_output['url'] = df_output['item_id'].apply(lambda x : 'https://www.amazon.com/dp/'+item_map[x])
    df_output = df_output[['user_id','item_id', 'score', 'asin', 'url', 'title', 'description', 'category', 'price']]
    
    #concat
    all_predicted_df = all_predicted_df.append(df_output)
# Out:
# selected 100 user_id: 113099
#
# Recommendations for user id 113099 Name: Angela Travis is:
# selected 100 user_id: 111238
#
# Recommendations for user id 111238 Name: A. Webb is:
# selected 100 user_id: 243987
#
# Recommendations for user id 243987 Name: Emily is:
# selected 100 user_id: 423151
#
# Recommendations for user id 423151 Name: Stephen Sobell is:
# selected 100 user_id: 243987
#
# Recommendations for user id 243987 Name: Emily is:
# selected 100 user_id: 180552
#
# Recommendations for user id 180552 Name: Penny Gwinn is:
# selected 100 user_id: 152976
#
# Recommendations for user id 152976 Name: BakingRaver is:
# selected 100 user_id: 75096
#
# Recommendations for user id 75096 Name: Mari23avelar is:
# selected 100 user_id: 199636
#
# Recommendations for user id 199636 Name: Reinvented is:
# selected 100 user_id: 183358
#
# Recommendations for user id 183358 Name: Patricia L. McQueary is:
# selected 100 user_id: 39965
#
# Recommendations for user id 39965 Name: Mrs. Z is:
# selected 100 user_id: 472996
#
# Recommendations for user id 472996 Name: Terry is:
# selected 100 user_id: 243987
#
# Recommendations for user id 243987 Name: Emily is:
# selected 100 user_id: 317217
#
# Recommendations for user id 317217 Name: Morgan Johnson is:
# selected 100 user_id: 44308
#
# Recommendations for user id 44308 Name: Rachel N. is:
# selected 100 user_id: 304656
#
# Recommendations for user id 304656 Name: JD is:
# selected 100 user_id: 409561
#
# Recommendations for user id 409561 Name: Marie S. is:
# selected 100 user_id: 44308
#
# Recommendations for user id 44308 Name: Rachel N. is:
# selected 100 user_id: 405883
#
# Recommendations for user id 405883 Name: Cali2ky2gr is:
# selected 100 user_id: 504420
#
# Recommendations for user id 504420 Name: Lisa Ramroop is:
# selected 100 user_id: 49839
#
# Recommendations for user id 49839 Name: M in SC is:
# selected 100 user_id: 423151
#
# Recommendations for user id 423151 Name: Stephen Sobell is:
# selected 100 user_id: 341119
#
# Recommendations for user id 341119 Name: Ross is:
# selected 100 user_id: 260347
#
# Recommendations for user id 260347 Name: Bodyreflexion is:
# selected 100 user_id: 484581
#
# Recommendations for user id 484581 Name: Ktddl is:
# selected 100 user_id: 155074
#
# Recommendations for user id 155074 Name: NashGatorGirl is:
# selected 100 user_id: 62758
#
# Recommendations for user id 62758 Name: Ian C is:
# selected 100 user_id: 47589
#
# Recommendations for user id 47589 Name: LUCLU is:
# selected 100 user_id: 116013
#
# Recommendations for user id 116013 Name: Tutt is:
# selected 100 user_id: 124732
#
# Recommendations for user id 124732 Name: Kendall is:
# selected 100 user_id: 8822
#
# Recommendations for user id 8822 Name: Kindle Customer is:
# selected 100 user_id: 211301
#
# Recommendations for user id 211301 Name: L. Neuman is:
# selected 100 user_id: 124732
#
# Recommendations for user id 124732 Name: Kendall is:
# selected 100 user_id: 124732
#
# Recommendations for user id 124732 Name: Kendall is:
# selected 100 user_id: 113099
#
# Recommendations for user id 113099 Name: Angela Travis is:
# selected 100 user_id: 160368
#
# Recommendations for user id 160368 Name: Tracy Thomson is:
# selected 100 user_id: 114498
#
# Recommendations for user id 114498 Name: kathleen mckeon is:
# selected 100 user_id: 404551
#
# Recommendations for user id 404551 Name: Mother, Artist, Writer, and Business Owner is:
# selected 100 user_id: 65009
#
# Recommendations for user id 65009 Name: Floweringink is:
# selected 100 user_id: 211301
#
# Recommendations for user id 211301 Name: L. Neuman is:
# selected 100 user_id: 295491
#
# Recommendations for user id 295491 Name: Chloe is:
# selected 100 user_id: 213073
#
# Recommendations for user id 213073 Name: Becky Phillips is:
# selected 100 user_id: 117168
#
# Recommendations for user id 117168 Name: CJ  is:
# selected 100 user_id: 36849
#
# Recommendations for user id 36849 Name: Andy L is:
# selected 100 user_id: 91971
#
# Recommendations for user id 91971 Name: Karen Peck is:
# selected 100 user_id: 326003
#
# Recommendations for user id 326003 Name: K. S. Hagee is:
# selected 100 user_id: 114498
#
# Recommendations for user id 114498 Name: kathleen mckeon is:
# selected 100 user_id: 91971
#
# Recommendations for user id 91971 Name: Karen Peck is:
# selected 100 user_id: 91971
#
# Recommendations for user id 91971 Name: Karen Peck is:
# selected 100 user_id: 341119
#
# Recommendations for user id 341119 Name: Ross is:
# selected 100 user_id: 260347
#
# Recommendations for user id 260347 Name: Bodyreflexion is:
# selected 100 user_id: 326003
#
# Recommendations for user id 326003 Name: K. S. Hagee is:
# selected 100 user_id: 409561
#
# Recommendations for user id 409561 Name: Marie S. is:
# selected 100 user_id: 260347
#
# Recommendations for user id 260347 Name: Bodyreflexion is:
# selected 100 user_id: 160368
#
# Recommendations for user id 160368 Name: Tracy Thomson is:
# selected 100 user_id: 101019
#
# Recommendations for user id 101019 Name: G. Vozzo is:
# selected 100 user_id: 113099
#
# Recommendations for user id 113099 Name: Angela Travis is:
# selected 100 user_id: 243987
#
# Recommendations for user id 243987 Name: Emily is:
# selected 100 user_id: 293682
#
# Recommendations for user id 293682 Name: ROBERT J. is:
# selected 100 user_id: 80589
#
# Recommendations for user id 80589 Name: SamanthaOleander is:
# selected 100 user_id: 416168
#
# Recommendations for user id 416168 Name: Amazon Customer is:
# selected 100 user_id: 62880
#
# Recommendations for user id 62880 Name: Stan D. is:
# selected 100 user_id: 18815
#
# Recommendations for user id 18815 Name: Nairovis is:
# selected 100 user_id: 70577
#
# Recommendations for user id 70577 Name: Against the grain is:
# selected 100 user_id: 18815
#
# Recommendations for user id 18815 Name: Nairovis is:
# selected 100 user_id: 49839
#
# Recommendations for user id 49839 Name: M in SC is:
# selected 100 user_id: 75096
#
# Recommendations for user id 75096 Name: Mari23avelar is:
# selected 100 user_id: 86030
#
# Recommendations for user id 86030 Name: Charlie is:
# selected 100 user_id: 309445
#
# Recommendations for user id 309445 Name: Annie is:
# selected 100 user_id: 317217
#
# Recommendations for user id 317217 Name: Morgan Johnson is:
# selected 100 user_id: 115440
#
# Recommendations for user id 115440 Name: S. O&#039;Donnell is:
# selected 100 user_id: 269438
#
# Recommendations for user id 269438 Name: shelly 1982 is:
# selected 100 user_id: 213073
#
# Recommendations for user id 213073 Name: Becky Phillips is:
# selected 100 user_id: 504420
#
# Recommendations for user id 504420 Name: Lisa Ramroop is:
# selected 100 user_id: 111238
#
# Recommendations for user id 111238 Name: A. Webb is:
# selected 100 user_id: 262540
#
# Recommendations for user id 262540 Name: Elka P. is:
# selected 100 user_id: 86155
#
# Recommendations for user id 86155 Name: M. Lee Taylor is:
# selected 100 user_id: 14904
#
# Recommendations for user id 14904 Name: K.C. is:
# selected 100 user_id: 369573
#
# Recommendations for user id 369573 Name: Sandra V is:
# selected 100 user_id: 62880
#
# Recommendations for user id 62880 Name: Stan D. is:
# selected 100 user_id: 65009
#
# Recommendations for user id 65009 Name: Floweringink is:
# selected 100 user_id: 160368
#
# Recommendations for user id 160368 Name: Tracy Thomson is:
# selected 100 user_id: 116013
#
# Recommendations for user id 116013 Name: Tutt is:
# selected 100 user_id: 293682
#
# Recommendations for user id 293682 Name: ROBERT J. is:
# selected 100 user_id: 22495
#
# Recommendations for user id 22495 Name: C Rasmussen MD, MS is:
# selected 100 user_id: 213073
#
# Recommendations for user id 213073 Name: Becky Phillips is:
# selected 100 user_id: 199636
#
# Recommendations for user id 199636 Name: Reinvented is:
# selected 100 user_id: 116013
#
# Recommendations for user id 116013 Name: Tutt is:
# selected 100 user_id: 39965
#
# Recommendations for user id 39965 Name: Mrs. Z is:
# selected 100 user_id: 63361
#
# Recommendations for user id 63361 Name: Tammy is:
# selected 100 user_id: 61497
#
# Recommendations for user id 61497 Name: M. Larimore is:
# selected 100 user_id: 44308
#
# Recommendations for user id 44308 Name: Rachel N. is:
# selected 100 user_id: 101019
#
# Recommendations for user id 101019 Name: G. Vozzo is:
# selected 100 user_id: 83361
#
# Recommendations for user id 83361 Name: EGL is:
# selected 100 user_id: 155741
#
# Recommendations for user id 155741 Name: CamEron is:
# selected 100 user_id: 163736
#
# Recommendations for user id 163736 Name: Chris Uppercut is:
# selected 100 user_id: 44308
#
# Recommendations for user id 44308 Name: Rachel N. is:
# selected 100 user_id: 75096
#
# Recommendations for user id 75096 Name: Mari23avelar is:
# selected 100 user_id: 19931
#
# Recommendations for user id 19931 Name: MuscleMan is:
# selected 100 user_id: 300850
#
# Recommendations for user id 300850 Name: Robin is:

# %%
all_predicted_df.to_csv('for_100_users_prediction.csv', header=True, index=False)
