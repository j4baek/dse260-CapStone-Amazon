# %%
import pandas as pd
import gzip
import json
import csv
import sys
import numpy as np
import time
from collections import defaultdict
from glob import glob
import gensim 
from gensim.models import Word2Vec 
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings 
import pyarrow
sys.path.append('./aws-glue-libs')
warnings.filterwarnings(action = 'ignore')

# %%
# !conda activate dse_env
from pyspark import SparkContext
from pyspark.sql import *

sc = SparkContext(master="local[3]")
sqlContext = SQLContext(sc)

DATA_DIR = './data/'
TABLE_NAME = 'landingZone/'
FILE_NAME = 'meta_Clothing_Shoes_and_Jewelry.json.gz'
PATH = DATA_DIR + TABLE_NAME + FILE_NAME

# %%
def readGz(f):
    for l in gzip.open(f):
        yield eval(l)

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
AWS_PROFILE = 'ucsd'
AWS_REGION = 'us-east-1'
AWS_ACCESS_KEY = 
AWS_SECRET_ACCESS_KEY = 
BUCKET_NAME = 
DATA_LAKE_SCHEMA = {
    "dse-cohort5-group1": {
        "data-lake-landing-zone": {
            "meta_Clothing_Shoes_and_Jewelry.json.gz",
            "Clothing_Shoes_and_Jewelry_5.json.gz",
            "reviews_Clothing_Shoes_and_Jewelry_5.json.gz"
        }
        "data-lake-standardization-zone": {
            "metaData.parquet": {}
        }
    }
}

# %%
from pyspark.sql import Row
class DataLake:
    def __init__(self):
        self.AWS_PROFILE = os.environ["AWS_PROFILE"]
        self.AWS_REGION = os.environ["AWS_REGION"]
        self.AWS_ACCESS_KEY = os.environ["AWS_ACCESS_KEY"]
        self.AWS_SECRET_ACCESS_KEY = os.environ["AWS_SECRET_ACCESS_KEY"]
        

    def generateFileName(self, folder, main_cat, sub_cat, gen_cat):
        self.DB_NAME = folder
        self.TABLE_NAME = main_cat
        self.SUB_CAT = sub_cat
        self.GEN_CAT = gen_cat
        self.FILE_NAME = '{s}_{g}.parquet'.format(s=self.SUB_CAT, g=self.GEN_CAT)
    
        self.PATH = './{d}/{f}/main_cat={m}/sub_cat={s}/gen_cat={g}/{fn}'.format(
            m=self.TABLE_NAME, 
            s=self.SUB_CAT, 
            d=self.BUCKET_NAME,
            f=self.DB_NAME,
            fn=self.FILE_NAME,
            g=self.GEN_CAT
        )
        
        return self.PATH
    
    def toJson(data):
        return json.loads(data)

    def parseCategory(d, main, sub, g):
        d['main_cat'] = main
        d['sub_cat'] = sub
        d['gender'] = g
        return d
    
    def genRDD(self, fn, main_cat, sub_cat, gen_cat):
        PATH = './{b}/{t}/{f}'.format(
            t='landingZone', 
            b=self.BUCKET_NAME,
            f=fn
        )
        
        self.data = self.sc.textFile(PATH)
        return self.data
        

        
        

DL = DataLake()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c37de8293a5e> in <module>
#       1 from pyspark.sql import Row
#       2
# ----> 3 rdd = sc.textFile(PATH)
#       4
#       5 def toJson(data):
#
# NameError: name 'sc' is not defined

# %%
import datetime

year = 2019

filename = './{d}/{f}/main_cat={m}/{fn}'.format(
    m='Clothing, Shoes & Jewelry', 
    s='reviews.parquet', 
    d='dataa',
    f='standardizationZone',
    t='reviews',
    fn='reviews.parquet'
)

def parseDate(d):
    d['unixReviewTime'] = datetime.datetime.utcfromtimestamp(d['unixReviewTime'])
    d['year'] = d['unixReviewTime'].year
    d['month'] = d['unixReviewTime'].month
    d['day'] = d['unixReviewTime'].day
    return d
    
reviewsRDD = rdd.map(lambda a: toJson(a)).map(lambda a: parseDate(a)).filter(lambda x: "year" == year)
reviewsRDD.take(3)

# %%
# Out:
# {'category': ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Flip-Flops', 'synthetic-and-fabric', 'Imported', 'Heel Height: 11cm=4.33",Platform: 5.5cm=2.17"', 'Material:EVA and cloth', 'Choose the usual size you wear, if you like loose, you could choos one size plus.', 'EVA rubber sole,comfortable,Handmade special occasion sandals'], 'fit': ' class="a-normal a-align-center a-spacing-small">\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Too small\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="21%"><div class="a-meter-bar" style="width: 21%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>4</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Somewhat small\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="5%"><div class="a-meter-bar" style="width: 5%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>1</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-state a-text-bold">\n                                    Fits as expected\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="63%"><div class="a-meter-bar" style="width: 63%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>12</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Somewhat large\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="10%"><div class="a-meter-bar" style="width: 10%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>2</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Too large\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="0%"><div class="a-meter-bar" style="width: 0%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>0</span>\n                            </td>\n                        </tr>\n                 ...
# [{'category': ['Clothing, Shoes & Jewelry',
#    'Costumes & Accessories',
#    'Kids & Baby',
#    'Girls',
#    'Accessories',
#    '3 layers of tulle',
#    '6" long, stretched waist measures 11 1/2" across. Fits up to 7 years.',
#    'Sequins line the edge of the tulle on the top layer.',
#    'Great for babys up to about age 7',
#    'Makes a Great gift for any princess'],
#   'description': ['6" long, stretched waist measures 11 1/2" across. Fits up to 7 years.'],
#   'title': 'Purple Sequin Tiny Dancer Tutu Ballet Dance Fairy Princess Costume Accessory',
#   'brand': 'Big Dreams',
#   'feature': ['3 layers of tulle',
#    '6" long, stretched waist measures 11 1/2" across. Fits up to 7 years.',
#    'Sequins line the edge of the tulle on the top layer.',
#    'Great for babys up to about age 7',
#    'Makes a Great gift for any princess'],
#   'rank': '19,963,069inClothing,ShoesJewelry(',
#   'date': '5 star5 star (0%)',
#   'asin': '0000037214'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Luggage & Travel Gear',
#    'Backpacks',
#    'Casual Daypacks',
#    'Polyester Canvas Waterproof',
#    'Imported',
#    'Size: Large (H 40 x W 26 x D 20cm)',
#    'Color: LIGHT GRAY & BLACK | Condition: 100% brand new',
#    '- Made of lightweight, durable and waterproof fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles'],
#   'description': ['The Hottest Bag in Town! Brand: Anello Condition: 100% brand new Size: Large Simplistic Japanese design to add spark to your style! Main compartment with a large capacity can fit numerous items! - a front zip pocket - 2 interior open pockets - bottle pocket on both sides - a zipper at the back - Made of lightweight, durable and waterproof fabric! - Roomy main compartment and multiple pockets for functionally - Comes with adjustable double shoulder straps and double top handles - Simple and stylish design that goes well with most outfits. Specifications: Size: approx. H 40 x W 26 x D 20cm Shoulder straps length: approx. 38-80cm (adjustable) Weight: approx. 650g Material: 600DOxford'],
#   'title': 'Japan Anello Backpack Unisex LARGE LIGHT GRAY BLACK Rucksack Waterproof Canvas Bag',
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/51RJoBQ2ANL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51rDea1EfUL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/4162SoyvdgL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/516pnw7cD1L._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51fZizR585L._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51BhSPzr2RL._SR38,50_.jpg'],
#   'brand': 'Anello',
#   'feature': ['Polyester Canvas Waterproof',
#    'Imported',
#    'Size: Large (H 40 x W 26 x D 20cm)',
#    'Color: LIGHT GRAY & BLACK | Condition: 100% brand new',
#    '- Made of lightweight, durable and waterproof fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles',
#    'Product Dimensions:\n                    \n15.8 x 7.9 x 10.2 inches',
#    'Shipping Weight:\n                    \n1.87 pounds'],
#   'rank': '4,537,420inClothing,ShoesJewelry(',
#   'date': '5 star',
#   'asin': '0201377179'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Luggage & Travel Gear',
#    'Backpacks',
#    "Kids' Backpacks",
#    'PU Leather',
#    'Imported',
#    'Size: Large PU Leather (H 39 x W 26 x D 16cm) Model: AT-B01211',
#    'Color: PINK BEIGE | Condition: 100% brand new',
#    '- Made of stylish, elegant and durable and PU leather fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles'],
#   'description': ['The Hottest Bag in Town! Brand: Anello Condition: 100% brand new Size: LARGE SIZE Material: PU Leather Simplistic Japanese design to add spark to your style! Main compartment with a large capacity can fit numerous items! Comes with a front zip pocket, 2 interior open pockets, 2 side bottle pockets and a zipper at the back! Made of stylish, elegant and durable PU leather fabric! - Roomy main compartment and multiple pockets for functionally - Comes with adjustable double shoulder straps and double top handles - Simple and stylish design that goes well with most outfits - Made of stylish, elegant and durable and PU leather fabric. Specifications: Size: approx. H 39 x W 26 x D 16cm Shoulder straps length: up to 84cm (adjustable) Weight: approx. 800g Material: PU Leather'],
#   'title': 'Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus',
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/518UiiWp-vL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51UGoyArGBL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51j9g8D1JbL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51hIGNRXJVL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51Abgdli4UL._SR38,50_.jpg'],
#   'brand': 'Anello',
#   'feature': ['PU Leather',
#    'Imported',
#    'Size: Large PU Leather (H 39 x W 26 x D 16cm) Model: AT-B01211',
#    'Color: PINK BEIGE | Condition: 100% brand new',
#    '- Made of stylish, elegant and durable and PU leather fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles',
#    'Product Dimensions:\n                    \n15.3 x 6.3 x 10.2 inches',
#    'Shipping Weight:\n                    \n1.98 pounds (View shipping rates and policies)'],
#   'rank': '3,994,472inClothing,ShoesJewelry(',
#   'also_view': ['B07CJF5HLR',
#    'B01EBI8UH6',
#    'B01N1LR908',
#    'B074M4QKGS',
#    '0204444403',
#    'B071YLMJ38',
#    'B01MSS59Y6',
#    'B01DLVYOPG',
#    '020444442X',
#    'B01G7IE3YC',
#    '0244444412',
#    'B01DLVYOQU',
#    'B071YBC1JS',
#    '0201377195',
#    'B01DLVYOME',
#    'B071KXFSXM',
#    '0204444470',
#    'B07CNH27PY',
#    'B01HQNP57Q',
#    'B01KSZZCOA',
#    'B07CYV9K11',
#    'B073YPXSZJ',
#    'B07CYS4M3F',
#    'B07DVVYYKV',
#    'B00UURAV66',
#    'B074FLMG56',
#    'B07C8J47HR',
#    'B078RNTJTF',
#    'B07H7BGGGL',
#    'B06W9K5ZQG',
#    'B01INM354Y'],
#   'date': '5 star',
#   'price': '$70.00',
#   'asin': '0204444454'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Luggage & Travel Gear',
#    'Backpacks',
#    "Kids' Backpacks",
#    'PU Leather',
#    'Imported',
#    'Size: Large PU Leather (H 39 x W 26 x D 16cm) Model: AT-B01211',
#    'Color: BLACK | Condition: 100% brand new',
#    '- Made of stylish, elegant and durable and PU leather fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles'],
#   'description': ['The Hottest Bag in Town! Brand: Anello Condition: 100% brand new Size: LARGE SIZE Material: PU Leather Simplistic Japanese design to add spark to your style! Main compartment with a large capacity can fit numerous items! Comes with a front zip pocket, 2 interior open pockets, 2 side bottle pockets and a zipper at the back! Made of stylish, elegant and durable PU leather fabric! - Roomy main compartment and multiple pockets for functionally - Comes with adjustable double shoulder straps and double top handles - Simple and stylish design that goes well with most outfits - Made of stylish, elegant and durable and PU leather fabric. Specifications: Size: approx. H 39 x W 26 x D 16cm Shoulder straps length: up to 84cm (adjustable) Weight: approx. 800g Material: PU Leather'],
#   'title': 'Japan Anello Backpack Unisex BLACK LARGE PU LEATHER Rucksack School Bag Campus',
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/514s3E59F1L._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51Ck7kicjFL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51UGoyArGBL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51j9g8D1JbL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51hIGNRXJVL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51Abgdli4UL._SR38,50_.jpg'],
#   'brand': 'Anello',
#   'feature': ['PU Leather',
#    'Imported',
#    'Size: Large PU Leather (H 39 x W 26 x D 16cm) Model: AT-B01211',
#    'Color: BLACK | Condition: 100% brand new',
#    '- Made of stylish, elegant and durable and PU leather fabric',
#    '- Roomy main compartment and multiple pockets for functionally',
#    '- a front zip pocket, 2 interior open pockets, bottle pocket on both sides, a zipper at the back. Adjustable double shoulder straps and double top handles',
#    'Product Dimensions:\n                    \n15.3 x 6.3 x 10.2 inches',
#    'Shipping Weight:\n                    \n1.72 pounds (View shipping rates and policies)'],
#   'rank': '635,761inClothing,ShoesJewelry(',
#   'also_view': ['B01DLVYOPG',
#    'B07CJF5HLR',
#    'B01MSS59Y6',
#    'B071YBC1JS',
#    'B01EBI8WQU',
#    'B01G7IE3YC',
#    'B01DLVYOME',
#    'B01EBI8UH6',
#    'B074M4QKGS',
#    '0244444692',
#    '024444420X',
#    '0201377195',
#    'B01DLVYOQU',
#    'B07KTY3WBM',
#    'B074FLMG56',
#    'B073YQCSBR',
#    'B07CYYQJN2',
#    'B07CYV9K11',
#    'B01G2QGM2K',
#    'B01N1LR908',
#    'B01HQNP57Q',
#    'B0784LMD7J',
#    '0204444454',
#    'B01DLVYKDC',
#    'B01N46SZV2',
#    'B01N76CA9D',
#    'B01NBWGCFI',
#    'B01GIVE44C',
#    'B073YPXSZJ',
#    '0244444412',
#    'B07613C6T3',
#    '0201344424',
#    '0204444462',
#    'B07CYXV3YX',
#    '0204444470',
#    'B07CYS4M3F',
#    'B07CZZY9FV',
#    'B078MLLLWQ',
#    'B076MJB5D8',
#    'B07CYZCV7Q',
#    'B073W63V63',
#    'B01DLVYK6Y',
#    'B07D6PFPHG',
#    '024444448X',
#    'B07CRQN3C9',
#    'B06W9K5ZQG',
#    'B01EBI8XBO',
#    '0244444269',
#    'B07H7BGGGL',
#    'B007PAN62C',
#    'B07514C9KX',
#    'B075VNTY8R',
#    'B01MTS4R4J',
#    'B07CNH27PY',
#    'B07BLL51QJ',
#    'B00UURAV66',
#    'B078QRFXYV'],
#   'date': '5 star',
#   'price': '$65.99',
#   'asin': '0204444403'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Women',
#    'Accessories',
#    'Hats & Caps',
#    'Baseball Caps',
#    'Imported',
#    'Plush,Cotton, Polyester',
#    'Lovely for look,Unisex for the normal adult',
#    'One size (approx 55-60 cm) adjustable',
#    'Unavailable alkaline detergent, (such as soap, laundry). With a mild detergent.'],
#   'description': ['Brand New.  Hat Centre Length: adult about 8cm (3.14 ")  Adult section Cap around: 55-60cm (21.65 "-23.62") adjustable hat around'],
#   'title': 'bettyhome Unisex Adult Winter Spring Thicken Cotton Hat Baseball Cap',
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/51ALk5zBu2L._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41NbZzQB7LL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/415cBb4qOWL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41tfDPo6TsL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41mAxFyc2eL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41benpCcxwL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41tj7mFigeL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41gjChrB3LL._SX38_SY50_CR,0,0,38,50_.jpg'],
#   'brand': 'bettyhome',
#   'feature': ['Imported',
#    'Plush,Cotton, Polyester',
#    'Lovely for look,Unisex for the normal adult',
#    'One size (approx 55-60 cm) adjustable',
#    'Unavailable alkaline detergent, (such as soap, laundry). With a mild detergent.',
#    'Shipping Information:\n                    \nView shipping rates and policies'],
#   'rank': '5,061,041inClothing,ShoesJewelry(',
#   'also_view': ['B00VGT93YS',
#    'B07FTY87LM',
#    'B01IKVOY8E',
#    'B01GF6C6F4',
#    'B00WH1RJPE',
#    'B01GGULZ74'],
#   'date': '5 star5 star (0%)',
#   'price': '$18.99',
#   'asin': '0206313535'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Swimsuits & Cover Ups',
#    'Cover-Ups',
#    'Imported',
#    'Bohemia style, butterfly printing',
#    'Length 30 ", Bust 40~45 "',
#    'Ice silk cotton,Very soft and comfortable',
#    'Unique style beach cover up for your bikinis and swimsuits make you more beautiful,fashion,sexy and elegant.'],
#   'description': ['Please allow 1-2cm dimension deviation. 100% brand new and in original package.  Due to Difference Computer Minitors,The Color Maybe slightly diffrent from picture'],
#   'title': 'bettyhome Womens Lace Short Sleeves Top Printing Butterfly Beach Cover-up Shirt',
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/51HNh00jdGL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51ZIWC6pb%2BL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41EAvsB2VAL._SR38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51Y%2B9hRb4KL._SX38_SY50_CR,0,0,38,50_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/413p8297xoL._SX38_SY50_CR,0,0,38,50_.jpg'],
#   'brand': 'bettyhome',
#   'feature': ['Imported',
#    'Bohemia style, butterfly printing',
#    'Length 30 ", Bust 40~45 "',
#    'Ice silk cotton,Very soft and comfortable',
#    'Unique style beach cover up for your bikinis and swimsuits make you more beautiful,fashion,sexy and elegant.',
#    'Shipping Information:\n                    \nView shipping rates and policies'],
#   'rank': '10,635,107inClothing,ShoesJewelry(',
#   'date': '5 star',
#   'price': '$23.99',
#   'asin': '0206335962'},
#  {'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Shoes',
#    'Sandals',
#    'Flip-Flops',
#    'synthetic-and-fabric',
#    'Imported',
#    'Heel Height: 11cm=4.33",Platform: 5.5cm=2.17"',
#    'Material:EVA and cloth',
#    'Choose the usual size you wear, if you like loose, you could choos one size plus.',
#    'EVA rubber sole,comfortable,Handmade special occasion sandals'],
#   'fit': ' class="a-normal a-align-center a-spacing-small">\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Too small\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="21%"><div class="a-meter-bar" style="width: 21%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>4</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Somewhat small\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="5%"><div class="a-meter-bar" style="width: 5%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>1</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-state a-text-bold">\n                                    Fits as expected\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="63%"><div class="a-meter-bar" style="width: 63%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>12</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Somewhat large\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="10%"><div class="a-meter-bar" style="width: 10%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>2</span>\n                            </td>\n                        </tr>\n                    \n                        <tr class="a-histogram-row">\n                            <td class="a-span3 a-nowrap">\n                                <span class="a-color-secondary">\n                                    Too large\n                                </span>\n                            </td>\n                            <td class="a-span7">\n                                <div class="a-meter" aria-label="0%"><div class="a-meter-bar" style="width: 0%;"></div></div>\n                            </td>\n                            <td class="a-span2 a-nowrap">\n                                <span>0</span>\n                            </td>\n                        </tr>\n                    \n                ',
#   'title': 'bettyhome Women Sexy Club Party Super High Heels 4.33 inch Comfortable Thongs Casual Wedges Sandals Beach Flip Flops Slippers',
#   'also_buy': ['B072LW94TG',
#    'B07BMBN792',
#    'B071DH8W2X',
#    'B01GF9AIOC',
#    'B073XGV3XW',
#    'B00B1I91FA'],
#   'image': ['https://images-na.ssl-images-amazon.com/images/I/51tzpun%2BBDL._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51-dywAacoL._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51IFvJixLcL._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51iFLuEvuoL._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51CY0WCBHzL._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51dXjWHQR6L._US40_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/41iQlOrYEOL._SS47_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/419huq52jfL._SS47_.jpg'],
#   'brand': 'bettyhome',
#   'feature': ['synthetic-and-fabric',
#    'Imported',
#    'Heel Height: 11cm=4.33",Platform: 5.5cm=2.17"',
#    'Material:EVA and cloth',
#    'Choose the usual size you wear, if you like loose, you could choos one size plus.',
#    'EVA rubber sole,comfortable,Handmade special occasion sandals',
#    'Shipping Information:\n                    \nView shipping rates and policies'],
#   'rank': '2,573,303inClothing,ShoesJewelry(',
#   'also_view': ['B07CHY4787', 'B073XGV3XW', 'B01GF9AIOC'],
#   'date': '5 star',
#   'price': '$31.99',
#   'asin': '0206323190'}]

# %%
# Out:
#           productId                                               data    id
# 0        0000037214  {'category': ['Clothing, Shoes & Jewelry', 'Co...  None
# 1        0201377179  {'category': ['Clothing, Shoes & Jewelry', 'Lu...  None
# 2        0204444454  {'category': ['Clothing, Shoes & Jewelry', 'Lu...  None
# 3        0204444403  {'category': ['Clothing, Shoes & Jewelry', 'Lu...  None
# 4        0206313535  {'category': ['Clothing, Shoes & Jewelry', 'No...  None
# ...             ...                                                ...   ...
# 2681352  B01HJHQR1W  {'category': ['Clothing, Shoes & Jewelry', 'No...  None
# 2681353  B01HJH8JBI  {'category': ['Clothing, Shoes & Jewelry', 'Me...  None
# 2681354  B01HJHFS58  {'category': ['Clothing, Shoes & Jewelry', 'Wo...  None
# 2681355           2                                               None  None
# 2681356           0                                               None  None
#
# [2681357 rows x 3 columns]

# %%
DATA_DIR = './dataa/landingZone/'
FILE_NAME = 'reviews_Clothing_Shoes_and_Jewelry_5.json.gz'
PATH = DATA_DIR + FILE_NAME

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')


df = getDF(PATH)
df.head()
# Out:
#        reviewerID        asin                 reviewerName helpful  \
# 0  A1KLRMWW2FWPL4  0000031887  Amazon Customer "cameramom"  [0, 0]
# 1  A2G5TCU2WDFZ65  0000031887              Amazon Customer  [0, 0]
# 2  A1RLQXYNCMWRWN  0000031887                       Carola  [0, 0]
# 3   A8U3FAMSJVHS5  0000031887                      Caromcg  [0, 0]
# 4  A3GEOILWLK86XM  0000031887                           CJ  [0, 0]
#
#                                           reviewText  overall  \
# 0  This is a great tutu and at a really great pri...      5.0
# 1  I bought this for my 4 yr old daughter for dan...      5.0
# 2  What can I say... my daughters have it in oran...      5.0
# 3  We bought several tutus at once, and they are ...      5.0
# 4  Thank you Halo Heaven great product for Little...      5.0
#
#                          summary  unixReviewTime   reviewTime
# 0  Great tutu-  not cheaply made      1297468800  02 12, 2011
# 1                    Very Cute!!      1358553600  01 19, 2013
# 2       I have buy more than one      1357257600   01 4, 2013
# 3               Adorable, Sturdy      1398556800  04 27, 2014
# 4        Grammy's Angels Love it      1394841600  03 15, 2014

# %%
# db = './dataa/standardizationZone/meta.parquet.gzip'
# productsDF.to_parquet(db, compression='gzip', partition_cols=['productId'])
# productsDF.to_pickle(dbp)
# productsDF.to_pickle("./dataa/standardizationZone/{}.pkl".format('meta'))
DATA_DIR = './dataa/landingZone/'
FILE_NAME = 'reviews_Clothing_Shoes_and_Jewelry_5.json.gz'
PATH = DATA_DIR + FILE_NAME

year = 2012
reviewsList = []
i = 0
for l in readGz(PATH):
    l['reviewTime'] = pd.to_datetime(l['reviewTime'])
    l['year'] = l['reviewTime'].year
    if l['year'] != year:
        continue
    else:
        l['month'] = l['reviewTime'].month
        l['day'] = l['reviewTime'].day
        # filename="./dataa/processedData/reviews/reviews.parquet"
# ndf.write.parquet(filename, mode='overwrite', partitionBy=['year', 'month', 'day'], compression='gzip')

        reviewsList.append(l)
    
reviewsList
# Out:
# [{'reviewerID': 'A2M2APVYIB2U6K',
#   'asin': '0000031887',
#   'reviewerName': 'Jamie P.',
#   'helpful': [0, 0],
#   'reviewText': "Great tutu for a great price. It isn't a &#34;full&#34; or high quality skirt, but it is perfect for my daughter to wear over leggings for her little outfits.",
#   'overall': 5.0,
#   'summary': 'Great value',
#   'unixReviewTime': 1356220800,
#   'reviewTime': Timestamp('2012-12-23 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 23},
#  {'reviewerID': 'A3EERSWHAI6SO',
#   'asin': '0000031887',
#   'reviewerName': 'Jeffrey Hollingshead "Jillian hollingshead"',
#   'helpful': [7, 8],
#   'reviewText': 'For what I paid for two tutus is unbeatable anywhere!  I ordered a pink and turquios and they are vibrant and beautiful! The tutu is very full! Princess style! Not cheaply made! Not cheap materia! Obviously someone made these with love and care! I paid less than 7 bucks for a tutu I and I feel proud of my self for researching to the point of finding gold!Recommend 2-6 years!My daughter is two ! Wears size 4t and this skirt ( one size ) fit perfect and will probaly be able to accommodate her quickly growing waist for some time!',
#   'overall': 5.0,
#   'summary': 'WOW !! ..is all I have to say!',
#   'unixReviewTime': 1349568000,
#   'reviewTime': Timestamp('2012-10-07 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 7},
#  {'reviewerID': 'A2SX7X8QGQVCJU',
#   'asin': '0000031887',
#   'reviewerName': 'Shannon',
#   'helpful': [0, 0],
#   'reviewText': 'My 4 year old daughter always wants to play dress up. I bought this for her for Christmas and she never wanted to take it off. It is almost a year later and she still has it!! It was well worth the money and has held up this long with nothing wrong with it!! I would recommend it',
#   'overall': 5.0,
#   'summary': 'My daughter loved it',
#   'unixReviewTime': 1351036800,
#   'reviewTime': Timestamp('2012-10-24 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 24},
#  {'reviewerID': 'A1WDJIFL2F4QJA',
#   'asin': '0123456479',
#   'reviewerName': 'Eddie',
#   'helpful': [1, 2],
#   'reviewText': 'This products is great for anyone with a lot of jewelry my girlfriend has a lot and this gift for her was one of my best ideas! i recommend this to any one with a lot of jewelry',
#   'overall': 5.0,
#   'summary': 'Amazing so many compartments',
#   'unixReviewTime': 1348444800,
#   'reviewTime': Timestamp('2012-09-24 00:00:00'),
#   'year': 2012,
#   'month': 9,
#   'day': 24},
#  {'reviewerID': 'A28QH3KX709FFQ',
#   'asin': '1608299953',
#   'reviewerName': 'Don Quixote "Don Q"',
#   'helpful': [24, 31],
#   'reviewText': "I bought this product a little over a year ago. Now that I am done with it, I wanted to sell it. I put it on eBay and Craigslist. They had their lawyers contact the sites and have them remove the listing.Apparently in the tiny 4-point font disclaimers on the package it says that the license is not transferable, so you can't sell it as a used item after you're done with it.Total crap !",
#   'overall': 1.0,
#   'summary': 'DO NOT BUY IF YOU EVER WANT TO RESELL IT.',
#   'unixReviewTime': 1348185600,
#   'reviewTime': Timestamp('2012-09-21 00:00:00'),
#   'year': 2012,
#   'month': 9,
#   'day': 21},
#  {'reviewerID': 'A35V32HZEGZH04',
#   'asin': '1608299953',
#   'reviewerName': 'W. Easley "Opa"',
#   'helpful': [2, 5],
#   'reviewText': '.When in the military,  I was stationed in Europe for several years.  The friends I made had a quiz they liked to use: "What do you call a person who speaks three languages? Trilingual;  What do you call a person who speaks two languages?  Bilingual; What do you call a person who speaks one language?  American.I have wanted to improve my language status for many years.  My High School Latin teacher said that after I learned Latin, the other romance languages would be easy.  I considered the other romance languages (Spanish, Portugese, Italian. Aragonese, Aromanian, Arpitan, Asturian, Corsican, Emiliano-Romagnolo, Friulan, Galician, Ladino, Leonese, Lombard, Mirandese, Neapolitan, Occitan, Piedmontese, Romansh, Sardinian, Sicilian, Venetian and Walloon), only the major four (French, Spanish, Italian, and Portugese were attractive to me, but then I saw this offer from Rosetta Stone and I chose French.Learning French was easier than I thought.  Of course the grammar I learned in my four years studying Latin made French grammar easier.  Well, and I did get a French grammar text and a French dictionary, since Rosetta Level 1 is limited in grammar.  After a few months using the interactive program, I began to feel comfortable speaking the language.I was tempted to brag to my family that I now speak French, then I realized that I had yet to converse in French with another human.  Soon I remembered my years living in Germany.  I had studied German, but could not really have a meaningful conversation with a German.  When I said something in German, they would answer in English (somehow they knew I was an American).  Those who did not speak English (maybe one percent of those I encountered) used a different dialect, and I was back to using my German book and pointing to words.  The lesson for me is that now I must spend some time in France if I really want to learn the language.  Oh well, I can read French as long as people do not get technical.Recently I thought of a possible answer to the dilemma I have with my European friends.  I could learn to speak Walloon, Friulan, and Arpitan.  I am unlikely to encounter anyone who speaks those languages, so no one to question whether I really know it.  Then I will tell them I am "quadri lingual.".  Do you think that will work? . . . Neither do I.',
#   'overall': 5.0,
#   'summary': 'Becoming Bilingual',
#   'unixReviewTime': 1328918400,
#   'reviewTime': Timestamp('2012-02-11 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 11},
#  {'reviewerID': 'A3I1BJIFFM4S21',
#   'asin': '1617160377',
#   'reviewerName': 'Atomicwasteland',
#   'helpful': [8, 8],
#   'reviewText': 'Never having studied Italian before, and never having used Rosetta Stone before, I was definitely excited to give it a go and find out what all the hype was about.I went through the whole lesson over the course of a couple of months, spending only about a day or two a week on it.In the end, I think it was a smart system, one that has specific advantages, but also marked disadvantages.POSITIVES:+++ IMMERSION TECHNIQUE -there is no English.  you will only see pictures and hear Italian.  This means you\'ll learn more effectively, as your brain is forced to make certain connections on its own.  Additionally, when you see pictures, for example, of a "male", the picture will be different each time: one time might be a young boy, and then it might be an old man, then a young man, and so on... and the first time you see the picture you might think it is a boy, but when the second picture pops up you realize that the word must mean something else, and you relate the two, and pick the commonality.  Anyway, this is a hard example, and it is simpler than this, but the idea is that you see different pictures representing each word, each time.++ WELL DESIGNED/VARIED -there are multiple modules which are scattered throughout -listening & comprehension, reading, pronunciation, typing, and so on.  It is impressive.++ GOOD REVIEWS -when I finished a section I was happy to find out that many of the concepts came back --not right away, but later when they weren\'t the freshest in my mind-- this meant I had to remember it, and basically memorized it through this recall.  I thought Rosetta Stone did a great job bringing up concepts and reminding me of the concepts later on.  I did not feel the need to review previous lessons...++ PAINLESS.  This system is about as fun (can I say that?) and as painless as a computer aided language learning system can get.NEGATIVES:--- PRICE, PRICE, PRICE -for most people the $200 cost for a single lesson (less as you buy more modules) is really too high.  Yes I know these things cost money, and I know they are better than other systems, but the pricing suggests that they are worried you won\'t like it, and you\'ll feel pressured to continue because you spent so much, OR, they are trying to convince you to pay only a few hundred more to get the whole set.  I\'d argue they\'d be better off dropping the price in half for the first module, and then I\'d recommend it more.  (And give me some sort of discount if I buy lesson 2 separately.  I am not going to buy multiple modules without buying the first one, and testing it out.  $500 for the set is too much of a committment without giving it a shot first.)- READING EXERCISES ARE BUGGY SOMETIMES -I have spent 5 minutes (unsuccessfully) on several sections where I am supposed to say just one syllable, and the voice recognition system fails.  I mean, I KNOW what I am hearing, I have studied 4 languages, have good pronunciation, and I can\'t for the life of me get the computer to believe I said "PO" (for example) instead of something unrecognizable.  It was very frustrating, as I tried to enunciate it every way imaginable, with no luck.  Yet, when It was a multi-syllabic word (with the same syllable) the computer had no problem.- NO DICTIONARY -yes, I know this isn\'t part of their system, but it would have been nice to have a dictionary so that I could learn some additional words on my own.  (Sometimes you just don\'t want to wait to lesson 5 to learn numbers, for example...)But probably the biggest criticism is that this program is no substitute for classroom participation.  (Yes, I know that there are some online modules that you can pay more for, but I wasn\'t interested in paying any more...)My wife was taking classroom Italian at the same time I was doing this system, and we would compare experiences.  One thing I noticed is that the "putting-sentences-together-on-my-own-and-saying-them" part of Rosetta Stone, was one of the weaker sections.  She, on the ...
#   'overall': 4.0,
#   'summary': 'Nice system, but way too expensive.',
#   'unixReviewTime': 1340150400,
#   'reviewTime': Timestamp('2012-06-20 00:00:00'),
#   'year': 2012,
#   'month': 6,
#   'day': 20},
#  {'reviewerID': 'A2BN9DIBP9A0XG',
#   'asin': '1617160377',
#   'reviewerName': 'D. Vance',
#   'helpful': [0, 0],
#   'reviewText': "I was thrilled to get the Rosetta Stone and be able to begin a lifelong desire to speak Italian!The software was very easy to load and use. The simple approach to learning a language as a child does was one terrific idea!I agree with other posters that to become fluent you will need to purchase more than just this level 1 program. However, this does allow you to learn some simple things and I do feel you could communicate enough to get your idea across.And, it is FUN to do! I'm enjoying it immensely!",
#   'overall': 5.0,
#   'summary': 'Great tool!',
#   'unixReviewTime': 1329696000,
#   'reviewTime': Timestamp('2012-02-20 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 20},
#  {'reviewerID': 'A2JCJJNY43QQIV',
#   'asin': '1617160377',
#   'reviewerName': 'Katy Lake',
#   'helpful': [6, 6],
#   'reviewText': "I have to admit, I was more impressed by Rosetta Stone than I thought I'd be. I learned French the old fashioned way (four years in high school and more in college), so the idea of taking on a new language in a way I had never tried before seemed like an interesting alternative.It was a lot more enjoyable than I thought it would be. I have a smattering of Italian from my family, and this added to it when I began to recognize words I had never seen before, but only heard.It installed on my Mac with no problems. I had a few issues with the microphone, but if you google it (there is help online), I found a fix that worked with little effort.I can't say Level 1 of Rosetta Stone is going to make you speak like a native, but after sampling this, it really does make you want to go onto the next phase, if it's as painless as this was.",
#   'overall': 4.0,
#   'summary': 'Nice start to a new language',
#   'unixReviewTime': 1337126400,
#   'reviewTime': Timestamp('2012-05-16 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 16},
#  {'reviewerID': 'A2VHNDYD9B8PGO',
#   'asin': 'B00001W0KA',
#   'reviewerName': 'Kathryn A. Mast',
#   'helpful': [0, 0],
#   'reviewText': "Good costume.  Very detailed.  I like that the body is a foam so it stands up a little on its own.  You might not be able to tell from the picture, but there are shin-guard type pieces for the legs, and gauntlets on the sleeves.  Nice touch.  It is a little thin overall.  You'll definitely want to put something underneath if you're in a colder climate.  My only disappointment is that the back of the torso is entirely black.  It's ok for us because I bought the inflatable wings, but without the wings, I think it would look weird.",
#   'overall': 4.0,
#   'summary': 'My son loved it!',
#   'unixReviewTime': 1353456000,
#   'reviewTime': Timestamp('2012-11-21 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 21},
#  {'reviewerID': 'A11Z8RVUCDYJAC',
#   'asin': 'B00001W0KA',
#   'reviewerName': 'Lori P',
#   'helpful': [0, 0],
#   'reviewText': 'My grandson wore this costume for Halloween. It was just as pictured and he had a blast wearing this along with tthe inflatable wings and helmet that we purchsed separately.',
#   'overall': 5.0,
#   'summary': 'Great Costume',
#   'unixReviewTime': 1355875200,
#   'reviewTime': Timestamp('2012-12-19 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 19},
#  {'reviewerID': 'A3SC04DC5TLYSP',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'Amanda Winstead',
#   'helpful': [8, 11],
#   'reviewText': "This pouch is lightweight and comfortable to wear, and I liked the very adjustable strap.  However, I would like for the pouch to be a couple of inches longer to accommodate the length of a standard boarding pass.  I was surprised that it was too short as it seems to me that travel documents would the the most likely thing to store here, but it could not be closed unless I bent the passes which then made them difficult to remove.  A minor gripe, overall I'm satisfied.",
#   'overall': 3.0,
#   'summary': 'Would like it to be a bit longer',
#   'unixReviewTime': 1335139200,
#   'reviewTime': Timestamp('2012-04-23 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 23},
#  {'reviewerID': 'A1X6ZPF88LTHGJ',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'Debra',
#   'helpful': [0, 0],
#   'reviewText': "I recently used this neck stash on a two week trip to France.  It was wonderful!  I loved it at the airport and at train stations, especially.  It is so helpful to have my hands free yet my passport and bording pass (or train ticket) ready to pull right out instead of fumbling in a purse.  I also carried money and credit cards in it and in extremely crowded tourist areas (like the Eiffel Tower) I wore it under my shirt for extra security.  It's lightweight and the adjustable neck strap, when adjusted properly, makes this pretty unnoticeable under a shirt.  I love the different compartments, as this makes it easier to find what you're looking for right away.",
#   'overall': 5.0,
#   'summary': 'Excellent travel accessory',
#   'unixReviewTime': 1350950400,
#   'reviewTime': Timestamp('2012-10-23 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 23},
#  {'reviewerID': 'A1UWE64CPO197G',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'Doug Martin',
#   'helpful': [0, 0],
#   'reviewText': "This neck stash is very comfortable and it's a nice size. There are two zippered pockets for cards, passports, cash, etc. and a large velcro flap for larger bills or boarding passes.",
#   'overall': 4.0,
#   'summary': 'Comfortable, Nice Size',
#   'unixReviewTime': 1345075200,
#   'reviewTime': Timestamp('2012-08-16 00:00:00'),
#   'year': 2012,
#   'month': 8,
#   'day': 16},
#  {'reviewerID': 'A3J9UVDJ5OZSSY',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'KLKota',
#   'helpful': [0, 2],
#   'reviewText': "I haven't used this yet, but I purchased it for my next trip. I already have a waist wallet, but I can't get to it without going to a restroom and partially undressing. This seemed much simpler to use.",
#   'overall': 4.0,
#   'summary': 'Deluxe Neck Stash',
#   'unixReviewTime': 1336435200,
#   'reviewTime': Timestamp('2012-05-08 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 8},
#  {'reviewerID': 'A2WN31HANFD17K',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'MollieOllieOxenFree',
#   'helpful': [0, 0],
#   'reviewText': "the last time i travelled i got one of the waist ones, and it was so annoying i never used it.  i haven't yet really used this one but i already feel much better about it.  i tried it out when i first opened the box when it came and wore it for a bit around my neck.  i don't like the toggle, but i doubled up the strap and tucked the toggle in the top flap of the stash and it works great.  i also wrapped it around my calf just below my knee to see if that would work too.  it worked just fine and i might wear it there when i wear my boots. i'm not sure if it really needs all those different departments, but that's ok. i don't think it's too big or too small.",
#   'overall': 4.0,
#   'summary': 'better than the last one i had',
#   'unixReviewTime': 1349481600,
#   'reviewTime': Timestamp('2012-10-06 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 6},
#  {'reviewerID': 'AIO4HX0KOLM73',
#   'asin': 'B00004SR8Z',
#   'reviewerName': 'Naynay',
#   'helpful': [1, 1],
#   'reviewText': 'This has a lot of pockets and yet is very slim. Took this on a trip outside of the US and the item was lightweight, discreet and very handy.  Holds 4 passports easily along with receipts.',
#   'overall': 5.0,
#   'summary': 'Very thin and easy to clean',
#   'unixReviewTime': 1355011200,
#   'reviewTime': Timestamp('2012-12-09 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 9},
#  {'reviewerID': 'A2HLAQL31J0IE1',
#   'asin': 'B00004SR9P',
#   'reviewerName': 'citykid',
#   'helpful': [1, 1],
#   'reviewText': "husband needed this strap to be able to attach his briefcase to his carry-on luggage to make navigating through the airport to the gate easier. product fits the bill, is well-made so it should hold up over time. he's already road-tested on a couple of recent trips and is happy with it.",
#   'overall': 5.0,
#   'summary': 'durable and functional',
#   'unixReviewTime': 1355616000,
#   'reviewTime': Timestamp('2012-12-16 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 16},
#  {'reviewerID': 'A3BGYK1ELD652P',
#   'asin': 'B00004SR9P',
#   'reviewerName': 'James Cook',
#   'helpful': [1, 1],
#   'reviewText': "I travel 3 weeks a month and carry 2 50 lb bags everywhere I go.  I have been using this strap for a couple months now to pull both bags together and it works awesome.  I wouldn't go back to traveling without it and the convenience for the price is great.I can even get both bags, when piggybacked, on an escalator and the strap is strong enough to hold the second bag in the air without snapping or anything.",
#   'overall': 5.0,
#   'summary': 'It Works For Me',
#   'unixReviewTime': 1337040000,
#   'reviewTime': Timestamp('2012-05-15 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 15},
#  {'reviewerID': 'A2K0D19N83G6U2',
#   'asin': 'B00004SR9P',
#   'reviewerName': 'Spoiled Rott\'n "Maria Olipas"',
#   'helpful': [11, 12],
#   'reviewText': 'If you\'re trying to connect two 50 lb suitcases together, this is not the strap to use. Look for the Travelon Multi-Bag Stacker, Black, One Size.This simple buckle and strap looks easy to use but it isn\'t. When you\'re in a hurry and you need to adjust the tension on this strap, you\'re fussing around with it in baggage claim. The Travelon Multi-Bag Stacker has extra "tongue" to quickly pull on (like a backpack strap) so you can clip, pull to tighten, and GO.This Lewis N Clark strap is good for light loads and smaller bags.  For larger ones, this one was a pain to use. You get what you pay for. Choke up the extra $5 and get the Travelon, you\'ll be glad you did.',
#   'overall': 2.0,
#   'summary': "I'm glad i bought back up straps",
#   'unixReviewTime': 1355875200,
#   'reviewTime': Timestamp('2012-12-19 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 19},
#  {'reviewerID': 'A8S94UH3I763R',
#   'asin': 'B00004SR9P',
#   'reviewerName': 'suible "suible"',
#   'helpful': [14, 14],
#   'reviewText': "It takes up very little space when not being used,  but has worked great in making it much easier to movie two pieces of luggage with one hand.My only caution is be sure that you snap the pieces together as they were intended to be snapped together. If you snap together with the one piece upside down, you'll need pliers to get them apart. So watch what you're doing and don't be stupid . . . or careless. And don't ask whether it was me or not who was stupid or careless.",
#   'overall': 5.0,
#   'summary': 'Small but great help in moving luggage',
#   'unixReviewTime': 1330300800,
#   'reviewTime': Timestamp('2012-02-27 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 27},
#  {'reviewerID': 'A1JKNP4BG4ZZ35',
#   'asin': 'B00004SR9P',
#   'reviewerName': 'Taeio Teague',
#   'helpful': [2, 2],
#   'reviewText': "We got several of these before our overseas (by plane) trip.  They came in very handy for stacking the bags and luggage we had to manhandle through customs, airports, into taxis & B & Bs, etc.  They were very easy to use & sturdy, and I recommend every traveler carry a couple for unexpected needs (to bind more than one thing together for easy carrying).  I used one every day in the rental car to hang my bags on (hung it from the head rest) so items didn't get tossed and lost.",
#   'overall': 5.0,
#   'summary': 'Luggage Straps -- Add-A-Bag',
#   'unixReviewTime': 1344038400,
#   'reviewTime': Timestamp('2012-08-04 00:00:00'),
#   'year': 2012,
#   'month': 8,
#   'day': 4},
#  {'reviewerID': 'A2XYM6A60U8M9S',
#   'asin': 'B00004U1J2',
#   'reviewerName': 'A. Bamba',
#   'helpful': [0, 0],
#   'reviewText': 'The Inflatable buzz lightyear costume jet pack did arrived on time.  My son did like it but it did not last long. It was OK gift for my son.',
#   'overall': 4.0,
#   'summary': 'good',
#   'unixReviewTime': 1353628800,
#   'reviewTime': Timestamp('2012-11-23 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 23},
#  {'reviewerID': 'APCU5MPM2Y0LY',
#   'asin': 'B00004U1J2',
#   'reviewerName': 'Lady Di "Diana"',
#   'helpful': [0, 0],
#   'reviewText': 'My boys are very much into the superhero stage, and these were perfect!!  They are inflatable back pieces, with white elastic straps similar to a backpack style.  The great thing is no one gets injured from being whacked with the wings of these mid-flight.  (as one who got smacked in the face while my Buzz was off to save the galaxy, I can vouch for that).  Price was great, these are super fun!',
#   'overall': 4.0,
#   'summary': 'Too Cute!',
#   'unixReviewTime': 1356652800,
#   'reviewTime': Timestamp('2012-12-28 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 28},
#  {'reviewerID': 'A3HY330W94JPUQ',
#   'asin': 'B000051SEN',
#   'reviewerName': 'Christian B. Cuyno',
#   'helpful': [0, 0],
#   'reviewText': "I don't know how many vector series watches I have bought. It is the basic Suunto model but it has everything that I need, not only for everyday use but for my job in the military.",
#   'overall': 5.0,
#   'summary': 'Favorite military watch.',
#   'unixReviewTime': 1354492800,
#   'reviewTime': Timestamp('2012-12-03 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 3},
#  {'reviewerID': 'A353P0P8WF325F',
#   'asin': 'B000051SEN',
#   'reviewerName': 'John',
#   'helpful': [0, 0],
#   'reviewText': 'Purchased at Bagram Afghanistan PX in 2007 and this watch is a must-have for anyone treking into the mountains (of which I did, alot).  Over the years the watch has taken a beating - the bezel is scratched up but, I still get a lot of comments about the watch.  The altimeter (incl the memory function) worked very well.  Battery replacement is easy (and has to occur about once a year).  The watch is a typical ABC watch, that looks good and does the job.',
#   'overall': 4.0,
#   'summary': 'Must have in Afghanistan',
#   'unixReviewTime': 1353628800,
#   'reviewTime': Timestamp('2012-11-23 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 23},
#  {'reviewerID': 'A2Z72LZNZEGN1S',
#   'asin': 'B00005JSBK',
#   'reviewerName': 'Amanda',
#   'helpful': [0, 0],
#   'reviewText': "Good lock, I use this for my gym locker and it serves it's purpose. I like that the color stands out so i don't have a hard time finding my locker(:",
#   'overall': 5.0,
#   'summary': 'good lock',
#   'unixReviewTime': 1355270400,
#   'reviewTime': Timestamp('2012-12-12 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 12},
#  {'reviewerID': 'A1YSVN7EBQZ5XT',
#   'asin': 'B00005KJXN',
#   'reviewerName': 'Nani',
#   'helpful': [0, 0],
#   'reviewText': "As it turns out, I didn't have a chance to use the costume but it seems to be well made.  Look forward to using it another time.",
#   'overall': 4.0,
#   'summary': 'Nun Costume',
#   'unixReviewTime': 1353196800,
#   'reviewTime': Timestamp('2012-11-18 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 18},
#  {'reviewerID': 'A1AP9XV3I1TOBK',
#   'asin': 'B00005KJXN',
#   'reviewerName': 'Tracy L. Mitchell',
#   'helpful': [0, 0],
#   'reviewText': "This came fast and it's of great quality! Perfect for the price, a little better actually. I am going to enjoy this ;)Happy Halloween!",
#   'overall': 5.0,
#   'summary': 'just perfect!',
#   'unixReviewTime': 1348704000,
#   'reviewTime': Timestamp('2012-09-27 00:00:00'),
#   'year': 2012,
#   'month': 9,
#   'day': 27},
#  {'reviewerID': 'A3RIOHLQHR44R6',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [0, 1],
#   'reviewText': 'I love this. It was cheap, and it is super cute and the kids just adore it. Anything to do with Dora is always a hit, and they felt like it was similar to her backpack...',
#   'overall': 4.0,
#   'summary': 'Cute!',
#   'unixReviewTime': 1356480000,
#   'reviewTime': Timestamp('2012-12-26 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 26},
#  {'reviewerID': 'A3HNCPACL5LNWP',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'Am Shopper',
#   'helpful': [0, 1],
#   'reviewText': 'I bought this for my 2 year old cousin. She has a habit of taking her mothers purse and walking all over with it so I figured it would be perfect. When I first saw it I fell in love with the soft material and girly colors and she absolutely loves it. She always remembers to put her things in her purse so she can be "just like mommy."',
#   'overall': 5.0,
#   'summary': 'sooo cute!',
#   'unixReviewTime': 1347840000,
#   'reviewTime': Timestamp('2012-09-17 00:00:00'),
#   'year': 2012,
#   'month': 9,
#   'day': 17},
#  {'reviewerID': 'A4S2GMZIQKEHY',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'Eldude',
#   'helpful': [0, 1],
#   'reviewText': 'My kids liked this and have fun playing around with it, the only thing I felt was the price could have been better. Saw it much cheaper at Walmart not too long ago and then believe it or not at the dollar store.However, the product itself is durable and nice, not kids hazards jumping right out or frail designs.',
#   'overall': 4.0,
#   'summary': 'nice but...',
#   'unixReviewTime': 1356739200,
#   'reviewTime': Timestamp('2012-12-29 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 29},
#  {'reviewerID': 'A1CIGMN879NSA',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'John Hargraves',
#   'helpful': [0, 0],
#   'reviewText': "I haven't actually gotten to see the product, but I got a call from my sister-in-law and she told me how much her daughter loves her first purse.  She said she carried it quite often and that it was a perfect gift for a 3 or 4 year old girl!",
#   'overall': 5.0,
#   'summary': 'My niece loves it!',
#   'unixReviewTime': 1354752000,
#   'reviewTime': Timestamp('2012-12-06 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 6},
#  {'reviewerID': 'AS4P74KQY9WR4',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'JO MO "JM"',
#   'helpful': [0, 0],
#   'reviewText': 'My neice loves it. She really likes the cell phone.  She is so cute with her little purse! She loves the little mirror in it.',
#   'overall': 5.0,
#   'summary': '1 yr old loves it!!!',
#   'unixReviewTime': 1354060800,
#   'reviewTime': Timestamp('2012-11-28 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 28},
#  {'reviewerID': 'A2SP9I25WTDDX',
#   'asin': 'B00005TQI7',
#   'reviewerName': 'P. Willie',
#   'helpful': [0, 0],
#   'reviewText': 'We bought this for our 15-mo old granddaughter. She liked carrying it around.  She played with the "Phone" and the "keys" that came with it and "used" the lipstick.  I liked that the handle was soft and the purse was a good size for toddlers.  I\'m sure she will continue to enjoy it over the next few years.',
#   'overall': 4.0,
#   'summary': 'Cute Purse',
#   'unixReviewTime': 1325462400,
#   'reviewTime': Timestamp('2012-01-02 00:00:00'),
#   'year': 2012,
#   'month': 1,
#   'day': 2},
#  {'reviewerID': 'AI82DQ7A2PRO7',
#   'asin': 'B0000643Q8',
#   'reviewerName': 'Janaster',
#   'helpful': [0, 0],
#   'reviewText': "Son's had his for 3-4 years. My 18 yr old son liked his so much. He even got compliments on it. Just bought another as a gift. It arrived in a frosted plastic display cube - looks nice. Good price for this watch.",
#   'overall': 5.0,
#   'summary': 'Light weight and sophisticated.. had 1, bought a 2nd as gift',
#   'unixReviewTime': 1353456000,
#   'reviewTime': Timestamp('2012-11-21 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 21},
#  {'reviewerID': 'A2N0NB969HDO9J',
#   'asin': 'B0000643Q8',
#   'reviewerName': 'vickyten',
#   'helpful': [0, 0],
#   'reviewText': 'Bought this for my husband-great watch.  However, we had to take to a jeweler to remove links.  Lightweight-goes with everything.',
#   'overall': 4.0,
#   'summary': 'skagen Titanium Watch',
#   'unixReviewTime': 1349481600,
#   'reviewTime': Timestamp('2012-10-06 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 6},
#  {'reviewerID': 'A2SK9YC54Y3XJ2',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Cynthia D. Alexander "horsesrus"',
#   'helpful': [0, 0],
#   'reviewText': 'what can i say stylish and comfortable black goes with everything,my husband has many pairs in assorted colors he likes the so much',
#   'overall': 5.0,
#   'summary': 'my husband lives in these',
#   'unixReviewTime': 1354060800,
#   'reviewTime': Timestamp('2012-11-28 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 28},
#  {'reviewerID': 'A2AUCIYXRNM4OZ',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'MARELYS YUSELYN MATA CALZADILLA',
#   'helpful': [0, 0],
#   'reviewText': 'these shoes are very cute and comfortable realmentes find them at a very affordable price more to give away this Christmas will be the perfect gift for my brother.',
#   'overall': 5.0,
#   'summary': 'black',
#   'unixReviewTime': 1355270400,
#   'reviewTime': Timestamp('2012-12-12 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 12},
#  {'reviewerID': 'A3BN9R498TGMOW',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Mary C. Castle "Mary stuck in Pittsburgh"',
#   'helpful': [0, 0],
#   'reviewText': 'I knew I had the best shoes when my then 10 year old cousin went nuts for my pink hi-tops a few years ago!And he was even more excited when I gave him the key to my SUV so he could see the new pair of limegreen ones I had just purchased.I think that I wore the pink ones while travelling in California a few years ago.  While we werehaving lunch in Santa Barbara one day, I noticed a store across the street and found some supportsthat allowed me to do even more walking while on that 2 week vacation.  I was in my late fiftiesat the time, and it was fun to see the expressions I got while wearing those shoes!!!  Since Imisplaced the old pink pair, I am now replacing them.  My favorite shoe of all time!!!Mary',
#   'overall': 5.0,
#   'summary': 'Love those pink hi-tops',
#   'unixReviewTime': 1331424000,
#   'reviewTime': Timestamp('2012-03-11 00:00:00'),
#   'year': 2012,
#   'month': 3,
#   'day': 11},
#  {'reviewerID': 'A33U4CWRJT22PN',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'MMF',
#   'helpful': [0, 0],
#   'reviewText': 'Got (the white) these for my 7 year old he loves them...they are realy cute and they fit him realy nice...Shoe is 100% and he says they are very comfortable',
#   'overall': 5.0,
#   'summary': 'REALY NICE',
#   'unixReviewTime': 1336089600,
#   'reviewTime': Timestamp('2012-05-04 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 4},
#  {'reviewerID': 'AAC6RJ4JNLLAT',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'natty',
#   'helpful': [0, 0],
#   'reviewText': 'I SEND THEM TO MY GREAT NIECE IN LAS VEGAS AND SHE LOVES THEM, EVERYONE KNOWS THE QUALITY OF CONVERSE, I HAVE BEEN WEARING THEM SINCE I WAS A CHILD MYSELF.',
#   'overall': 5.0,
#   'summary': 'LOVE THESE SHOES',
#   'unixReviewTime': 1356825600,
#   'reviewTime': Timestamp('2012-12-30 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 30},
#  {'reviewerID': 'A29Y5EKP7ZIPY',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Orion Paden',
#   'helpful': [0, 0],
#   'reviewText': "I love my black on black converse tennis shoes, straightgangsta! Now this is my style. It goes with any I wearthat's casual or street wear. Thank you.",
#   'overall': 5.0,
#   'summary': 'Orion Paden',
#   'unixReviewTime': 1339200000,
#   'reviewTime': Timestamp('2012-06-09 00:00:00'),
#   'year': 2012,
#   'month': 6,
#   'day': 9},
#  {'reviewerID': 'A1L15VDRPWAH16',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Rathanator',
#   'helpful': [0, 0],
#   'reviewText': 'Bought as a replacement for kid brother. Item as describe! Size is true and recommended for teens since shoe does not go out of style.',
#   'overall': 5.0,
#   'summary': 'Cheapest price online and retail',
#   'unixReviewTime': 1355875200,
#   'reviewTime': Timestamp('2012-12-19 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 19},
#  {'reviewerID': 'APWY6UMP4N1JK',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Shawn Smith',
#   'helpful': [0, 0],
#   'reviewText': 'i think that this sneaker was a bit tight but otherwise a good buy. waiting to procure a similar item.',
#   'overall': 3.0,
#   'summary': 'not bad',
#   'unixReviewTime': 1335052800,
#   'reviewTime': Timestamp('2012-04-22 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 22},
#  {'reviewerID': 'A3U5HKDHPYBAK3',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'Thomas P. Troyer',
#   'helpful': [0, 0],
#   'reviewText': 'The Converse Unisex Chuck Taylor All Star Hi-Tops were a gift that I gave to my Nephew from the Netherlands. This is what he picked out from many possible choices. They were sent to him and as far as I know he liked them very much. Apparently, they were very popular in Holland. He was 16 at the time and in high school.',
#   'overall': 5.0,
#   'summary': 'Converse shoes',
#   'unixReviewTime': 1355702400,
#   'reviewTime': Timestamp('2012-12-17 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 17},
#  {'reviewerID': 'A2T9IH16GY393F',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'WalkezWoman',
#   'helpful': [0, 0],
#   'reviewText': "It's a Chuck Taylor through and through. Not much support but I don't care. These were for my son and he wears a custom orthotic anyway. So we just dropped it in and he was good to go. He wore these with his tux for the prom. He was stylin' and comfortable. I do recommend going up 1/2 size if you have narrow feet and a full size if you have a medium width because they run a bit short.",
#   'overall': 4.0,
#   'summary': "It's a Chuck!",
#   'unixReviewTime': 1339113600,
#   'reviewTime': Timestamp('2012-06-08 00:00:00'),
#   'year': 2012,
#   'month': 6,
#   'day': 8},
#  {'reviewerID': 'A2182PKLBKXADO',
#   'asin': 'B00006XXGO',
#   'reviewerName': 'xmx',
#   'helpful': [1, 6],
#   'reviewText': "My son only wore these shoes once (he's only 2) because they cause so much distress to get on and off, we just don't bother anymore. Why they dont make a  hidden zip for the toddler sizes is beyond me. They're expensive so wait until they're older before buying this type of shoe.",
#   'overall': 2.0,
#   'summary': "Wait until they're older",
#   'unixReviewTime': 1335139200,
#   'reviewTime': Timestamp('2012-04-23 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 23},
#  {'reviewerID': 'AMVC9WTXYKNJ1',
#   'asin': 'B0000722HK',
#   'reviewerName': 'J. Edgar Mihelic "Skyscraper"',
#   'helpful': [0, 0],
#   'reviewText': 'I fell in love with Under Armour\'s products four years ago, and that hasn\'t changed.They were still a niche brand then, on the edge of coming into their own as a major brand in the marketplace.These shirts and their whole line of ...Gear products are the reason why. They had a quality product before the image was built.I stayed away at first, not thinking that an undershirt could be worth the twenty-five clams. I tried some of the competitors first, but a friend of mine was such an advocate I had to try at least one. I\'m glad I did. The HeatGear material is perfect. It is firm enough that it does it job in compression -- for me, that means keeping my jiggly bits in place when I work out -- but it is not too tight or thick.I have both the sleeveless and the sleeved version. I like the sleeveless version for working out, because it helps your range of motion with your arms. The sleeved version is nice as an undershirt, but the only problem in that context is that they place their logo on the chest with a high contrast so it shines through the outer shirt. UA has started to offer a sleeved "Tactical" version of the shirt, which I might buy one or two, but the color choices are limited.They do what they advertise; the material spreads the sweat out and it evaporates faster than cotton.  The hold you in place.  You are not as hot as some may be while working hard.  You are armoured.These are entirely worth the money, and I recommend that you buy a half-dozen or so as soon as you can.',
#   'overall': 5.0,
#   'summary': 'You are armoured',
#   'unixReviewTime': 1330732800,
#   'reviewTime': Timestamp('2012-03-03 00:00:00'),
#   'year': 2012,
#   'month': 3,
#   'day': 3},
#  {'reviewerID': 'A3016MBSDQOECO',
#   'asin': 'B0000722HK',
#   'reviewerName': 'Nathan',
#   'helpful': [0, 0],
#   'reviewText': 'This shirt feels great at the gym.  It limits the outward appearance of sweat, allows for your body to cool off while working hard.. Comfort is key when working out, and so is working out and not have to worry if you have giant pit stains.  Wonderful shirt',
#   'overall': 5.0,
#   'summary': 'HeatGear',
#   'unixReviewTime': 1329091200,
#   'reviewTime': Timestamp('2012-02-13 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 13},
#  {'reviewerID': 'A26X8829IISSA2',
#   'asin': 'B0000722HK',
#   'reviewerName': 'Ran',
#   'helpful': [0, 0],
#   'reviewText': 'is the 3rd time i buy compression shirts and is always a great thing to do, other brands or kinds are just not good enough, high quality and low price is all i need',
#   'overall': 5.0,
#   'summary': 'Amazing as always',
#   'unixReviewTime': 1329350400,
#   'reviewTime': Timestamp('2012-02-16 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 16},
#  {'reviewerID': 'AFNYEP9UND180',
#   'asin': 'B0000722HK',
#   'reviewerName': 'Steve',
#   'helpful': [0, 0],
#   'reviewText': "there are alot of rip-offs for under armour products these days and I'm not gonna lie... I've tried a few of them to save a little money. but i ended up being very disappointed every time. then going back and spending extra just to buy the under armour to replace it. it is such a great line of products, and very versatile. i use it for hunting, i use it for running, i use it at work. it's worth the extra money because i know whenever i buy under armour, it's going to be a solid product. keep up the great work.",
#   'overall': 5.0,
#   'summary': "it's under armour... need i say more.",
#   'unixReviewTime': 1339200000,
#   'reviewTime': Timestamp('2012-06-09 00:00:00'),
#   'year': 2012,
#   'month': 6,
#   'day': 9},
#  {'reviewerID': 'A2P2QNLH3M4IIT',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'believer033',
#   'helpful': [0, 0],
#   'reviewText': "My 4 yr old son needed black shoes for a play he was in. I didn't want to buy dress shoes as he would not get any additional wear out of them. I opted for these black Converse. They were adorable, they fit him well - he is about a size 11 little kids but I ordered the 12 and they are fine with a bit of growing room.  He calls them his &#34;Chucks&#34; and thinks he's cool when he wears them...well, he is pretty cool - he has worn them several times since the play so overall, it was a good purchase.",
#   'overall': 5.0,
#   'summary': 'Good Choice',
#   'unixReviewTime': 1355961600,
#   'reviewTime': Timestamp('2012-12-20 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 20},
#  {'reviewerID': 'A2TY9KJ0B5LI0P',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'bsassy406',
#   'helpful': [0, 0],
#   'reviewText': 'These run bigger than normal tennis shoes...my son has only worn these since he was born. We are on our 19th pair and get tons of use out of them!!',
#   'overall': 5.0,
#   'summary': 'Run big',
#   'unixReviewTime': 1355270400,
#   'reviewTime': Timestamp('2012-12-12 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 12},
#  {'reviewerID': 'A122ULM3MEHFW7',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Danielle Chavez',
#   'helpful': [0, 0],
#   'reviewText': 'I GOT MY SHOES IN THE MAIL VERY FAST I LOVE THEM THEY GO WITH EVERYTHING I WEAR I RECOMMEND YOU BUY THEM.',
#   'overall': 5.0,
#   'summary': 'I Love These Shoes',
#   'unixReviewTime': 1354752000,
#   'reviewTime': Timestamp('2012-12-06 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 6},
#  {'reviewerID': 'AD5XV8AMXOH7W',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Fabio Muoz "fabio muoz"',
#   'helpful': [0, 0],
#   'reviewText': 'zapatos de excelente calidad, muy comodos para realizar cualquier actividad llegaron en el tiempo acordado y sin ninguna novedad los recomiendo ampliamente',
#   'overall': 5.0,
#   'summary': 'producto original',
#   'unixReviewTime': 1353888000,
#   'reviewTime': Timestamp('2012-11-26 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 26},
#  {'reviewerID': 'A27CTW0GPEE0AZ',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Firefly',
#   'helpful': [0, 0],
#   'reviewText': 'Very nice looking shoe and very comfortable !! You can wear them all day and no problems.I bought them for my daughter and she loves them .',
#   'overall': 5.0,
#   'summary': 'EXCELLENT !!!',
#   'unixReviewTime': 1349827200,
#   'reviewTime': Timestamp('2012-10-10 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 10},
#  {'reviewerID': 'A3IRS1AY45IWXR',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Kevin Haley',
#   'helpful': [0, 0],
#   'reviewText': "I had to get these for a wedding.  Let's just say technology has made more modern shoes more comfortable. Liked 'em more when I was 8.",
#   'overall': 3.0,
#   'summary': "Payin' for the Name?",
#   'unixReviewTime': 1334534400,
#   'reviewTime': Timestamp('2012-04-16 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 16},
#  {'reviewerID': 'A7SFWNWQPCSQH',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Medusa',
#   'helpful': [0, 0],
#   'reviewText': "These shoes are true to size, are authentic converse, are comfortable, and arrived on time and in the correct color.  My only complaint about converse is that they are a bit too narrow. However you can find them at pretty much any shoe store so you can always try them on first before you buy them.  I am happy about the price too (they were $10 more expensive at DSW than here on amazon).  They don't offer much in terms of arch support, but overall I can't complain.",
#   'overall': 4.0,
#   'summary': 'Good everyday shoes',
#   'unixReviewTime': 1336089600,
#   'reviewTime': Timestamp('2012-05-04 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 4},
#  {'reviewerID': 'AC09OIFJYTUQK',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'MF',
#   'helpful': [0, 2],
#   'reviewText': "I've bought these for work, where I stand for an average of 8 hrs at a time.Comfortable, great traction, inexpensive.",
#   'overall': 3.0,
#   'summary': 'Worth the price.',
#   'unixReviewTime': 1353456000,
#   'reviewTime': Timestamp('2012-11-21 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 21},
#  {'reviewerID': 'AVYL2UCQ45W9L',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'roses',
#   'helpful': [1, 2],
#   'reviewText': 'These are a vibrant pink and I get lots of compliments!  As usual, Converse run a half size too large and no support.',
#   'overall': 3.0,
#   'summary': 'a feminine converse?',
#   'unixReviewTime': 1355443200,
#   'reviewTime': Timestamp('2012-12-14 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 14},
#  {'reviewerID': 'A12X3J7IITW1J6',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'Sammi D',
#   'helpful': [1, 1],
#   'reviewText': 'I love converse SO much. i wore my old ones until they had holes in them and were falling apart. i just got these and of course I LOVE THEM. they are 100% REAL AUTHENTIC converse. the shipping was extremely fast, and very safely packaged :) thank you so much',
#   'overall': 5.0,
#   'summary': 'LOVE',
#   'unixReviewTime': 1339372800,
#   'reviewTime': Timestamp('2012-06-11 00:00:00'),
#   'year': 2012,
#   'month': 6,
#   'day': 11},
#  {'reviewerID': 'A1L92F4Q5UP5D7',
#   'asin': 'B000072UMJ',
#   'reviewerName': 'y2k',
#   'helpful': [0, 1],
#   'reviewText': "I bought these for my 13 yr old son.  They cost about the same price at the mall but it's always a plus when you can avoid going to the mall.  Chuck's run larger so you have to get a size smaller than what you would normally wear.  I found that out when I had to do a return and reorder.  Other than that, he seems to like his Chuck's.  I've bought a few more in different colors because he likes them so much.",
#   'overall': 4.0,
#   'summary': 'Save the trip to the mall',
#   'unixReviewTime': 1354665600,
#   'reviewTime': Timestamp('2012-12-05 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 5},
#  {'reviewerID': 'A1CQ5Y7E6WVYL6',
#   'asin': 'B000074RL3',
#   'reviewerName': 'Bike Chick',
#   'helpful': [0, 0],
#   'reviewText': 'This is the only sports bra that I have ever worn that can also be used as a minimizer as well. It worked very good at flattening my big chest making it impossible for the big huge sacks I call breast to even budge one centimeter.The downfalls of this bra is that it is hard to put on the first time and really does not break in and feel comfortable and natural until you have worn the thing many times. Also it took time to put the bra on as it has over 10 hooks to fasten painstakingly one at a time.However, the positive is that I had this same model bra for over 2 years and has survived constant wear, tear, and abuse.To sum up this review it is worth the money if you are up to enduring some discomfort until the bra breaks in and is looking for an excellent minimizer.AS for an actual sports bra for activities where you will be doing alot of moving and flexing of the upper body I do not recommend this bra. You might want to try the Moving Comfort line as they have excellent support for big chests.',
#   'overall': 4.0,
#   'summary': 'Great sports bra excellent support also makes a good minimizer',
#   'unixReviewTime': 1352073600,
#   'reviewTime': Timestamp('2012-11-05 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 5},
#  {'reviewerID': 'A11WYHDB1YEZOX',
#   'asin': 'B000074RL3',
#   'reviewerName': 'Jackie-the-Greyhound',
#   'helpful': [2, 2],
# ...
#   'summary': 'Sock It to Em!',
#   'unixReviewTime': 1350777600,
#   'reviewTime': Timestamp('2012-10-21 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 21},
#  {'reviewerID': 'A13ZRACMTM4ENB',
#   'asin': 'B0002TOZ1Y',
#   'reviewerName': 'N. Robertson',
#   'helpful': [0, 0],
#   'reviewText': "My son loves these socks and says they are a great fit and don't twist. I would highly reccommend. Buy these and you will not regret.",
#   'overall': 5.0,
#   'summary': 'Great socks',
#   'unixReviewTime': 1353974400,
#   'reviewTime': Timestamp('2012-11-27 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 27},
#  {'reviewerID': 'A2VNAGUP6GD6ZW',
#   'asin': 'B0002TOZ1Y',
#   'reviewerName': 'Scott (Technogeek)',
#   'helpful': [0, 0],
#   'reviewText': 'These are quality bulk socks that have held up well for me. I like the quarter height and the stretch holds up through many washings.Update! Still holding up well. I will continue to purchase them.',
#   'overall': 5.0,
#   'summary': 'Quality Socks',
#   'unixReviewTime': 1330214400,
#   'reviewTime': Timestamp('2012-02-26 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 26},
#  {'reviewerID': 'A2A0XVXWTZGW1I',
#   'asin': 'B0002TOZ1Y',
#   'reviewerName': 'V. Do',
#   'helpful': [0, 0],
#   'reviewText': "Pros:-Very comfortable fit! My shoe size is 8.5 and I got the 10-13/Shoe:6-12.5 sized socks-Will last long thanks to the thick cotton layer-Elastic on the ankle is just right. Not too tight or loose. Won't slip downCons:-I don't like the yellow color, prefer all white but they wouldn't be called Gold Toe socks for a reason",
#   'overall': 5.0,
#   'summary': 'Comfy socks',
#   'unixReviewTime': 1333929600,
#   'reviewTime': Timestamp('2012-04-09 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 9},
#  {'reviewerID': 'A1G5FIEA40QCT4',
#   'asin': 'B0002TOZ1Y',
#   'reviewerName': 'zzzrn',
#   'helpful': [0, 0],
#   'reviewText': 'These socks are super comfortable and the retain their shape wash after wash.  They worn for 12 hour shift work and the reamin comfortable the entire shift.',
#   'overall': 5.0,
#   'summary': 'Excellent product',
#   'unixReviewTime': 1336262400,
#   'reviewTime': Timestamp('2012-05-06 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 6},
#  {'reviewerID': 'A3PD8JD9L4WEII',
#   'asin': 'B0002TOZ2S',
#   'reviewerName': 'Bron "Bron"',
#   'helpful': [1, 1],
#   'reviewText': 'I like these low cut socks, but most of the "one size fits all" (usually 6-12 shoe size) that I\'ve found are far too tight on my feet and ankles, cutting off circulation - unhealthy and uncomfortable.  I wear a size 10 1/2- 11 man\'s shoe.  These are a perfect fit.  They are very comfortable, not too tight, and they do not cut into my skin like the smaller kind do.  I am very happy to have found these.  I have had no problems (so far, anyway) with them slipping or coming off/down, they seem fine.  I hardly notice them which is exactly what I want.The material seems fine to me as well.  Not thick, but thick enough, and I very much like that the band around the top (at your ankles) is not a super tight noose, but just tight enough to do the job.  The bottom part has enough material to be comfortable without being overly thick and seems of decent quality.If I have any problems later, I will come back and post, but I am giving these a big thumbs up at this time.20212-02-17 Update: If you like these and want something in the higher cut style, look here:Gold Toe Men\'s Cotton Crew Athletic Sock, 6-Pack- I tried them and they are equally good and not too tight.',
#   'overall': 5.0,
#   'summary': 'Perfect!  Very comfortable and not too tight!',
#   'unixReviewTime': 1328832000,
#   'reviewTime': Timestamp('2012-02-10 00:00:00'),
#   'year': 2012,
#   'month': 2,
#   'day': 10},
#  {'reviewerID': 'A1LE1UU0C3RSUK',
#   'asin': 'B0002TOZ2S',
#   'reviewerName': 'J. Threlkeld "JT"',
#   'helpful': [0, 0],
#   'reviewText': "I'm a size 12 or 13 shoe and I bought these because I was having trouble fitting into socks that were made for shoe sizes up to size 12.  I bought these extended size because they supposedly fit up to size 16 shoe.  I was worried they would be way too big but in fact, I would say these barely fit my feet.  I would think someone who was size 14 and up would still find these small.Other than that, the socks are fine.  They're still pretty thin... even on the 'cushioned' bottom part of the sock but I wasn't expecting a lot of cushion at this price.",
#   'overall': 4.0,
#   'summary': 'Nice but not very big',
#   'unixReviewTime': 1349740800,
#   'reviewTime': Timestamp('2012-10-09 00:00:00'),
#   'year': 2012,
#   'month': 10,
#   'day': 9},
#  {'reviewerID': 'A1D1782JK9GDNE',
#   'asin': 'B0002TOZ2S',
#   'reviewerName': 'the guru "I live on amazon"',
#   'helpful': [0, 0],
#   'reviewText': "This is a DEAL! these socks are very good quality, they are thick and comfortable. They stretch and they don't shrink too bad in the dryer. I would definitely purchase these again. I use these as gym socks and they are great for any kind of training, walking, running, or even daily use. My only complaint is after several washes they still lint pretty heavily on the bottom of your feet when you take the socks off. Outside of that I love them.",
#   'overall': 5.0,
#   'summary': 'Very Comfy Socks! Great quality',
#   'unixReviewTime': 1352332800,
#   'reviewTime': Timestamp('2012-11-08 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 8},
#  {'reviewerID': 'A1VYYBJZ22BCL5',
#   'asin': 'B0002TOZ2S',
#   'reviewerName': 'tuoder "Michael Witham"',
#   'helpful': [0, 0],
#   'reviewText': "These seem to be made pretty well, and while I can't comment on longevity yet, I anticipate these will last me a while.Of course, they do have a bit of a tendency to fall below your ankle if you wear slip-on shoes (I do.). My shoe size is 11.5 M so YMMV.So I'd say they're pretty good for most people.",
#   'overall': 4.0,
#   'summary': 'Good, inexpensive low black sock.',
#   'unixReviewTime': 1346716800,
#   'reviewTime': Timestamp('2012-09-04 00:00:00'),
#   'year': 2012,
#   'month': 9,
#   'day': 4},
#  {'reviewerID': 'A2P6KPSD5S0MY6',
#   'asin': 'B0002TOZ2S',
#   'reviewerName': 'William C. Everett',
#   'helpful': [0, 0],
#   'reviewText': "I have a size 13-14 foot and these still peek out from my loafers and tennis shoes. That said, they're pretty comfortable and don't slide down my ankle. They feel just a little baggy, but that's better than being too tight. Overall pretty good quality for the price.",
#   'overall': 4.0,
#   'summary': 'Reasonably good socks',
#   'unixReviewTime': 1342396800,
#   'reviewTime': Timestamp('2012-07-16 00:00:00'),
#   'year': 2012,
#   'month': 7,
#   'day': 16},
#  {'reviewerID': 'A15PUBCS4N4G60',
#   'asin': 'B0002TVB70',
#   'reviewerName': 'buckeyede06',
#   'helpful': [0, 0],
#   'reviewText': 'These will do the job on small scuffs and everyday wear and tear marks. Just dont expect them to much more. After trying to remove a few light marks from grease or mud, i found these to be ineffective. They are only ok at some of these types of marks. I would recommend for light wear but these just dont cut it for anything more intense.',
#   'overall': 3.0,
#   'summary': 'Works for minor scuffs',
#   'unixReviewTime': 1356912000,
#   'reviewTime': Timestamp('2012-12-31 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 31},
#  {'reviewerID': 'A1HU1EK0PBUYG7',
#   'asin': 'B0002TVB70',
#   'reviewerName': 'Happyteri',
#   'helpful': [1, 1],
#   'reviewText': 'I ordered one of these a month or so ago.  I was so pleased with it that I ordered 2 more so I could have 1 for work and a second one at home for my daughter.  Good price on a no-nonsense product.',
#   'overall': 5.0,
#   'summary': 'Great',
#   'unixReviewTime': 1326412800,
#   'reviewTime': Timestamp('2012-01-13 00:00:00'),
#   'year': 2012,
#   'month': 1,
#   'day': 13},
#  {'reviewerID': 'A3DLS3U29UXQN5',
#   'asin': 'B0002TVB70',
#   'reviewerName': 'Mountain Mama',
#   'helpful': [1, 1],
#   'reviewText': 'I will not go into what this did not do for stains across the toes of a pair of boots - but it did not even clean the dust out of the top of the boots (no staining or visible dirt there, just dusty)Could not recommend this product at all!',
#   'overall': 1.0,
#   'summary': "Don't Waste Your Money",
#   'unixReviewTime': 1337558400,
#   'reviewTime': Timestamp('2012-05-21 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 21},
#  {'reviewerID': 'A1MGZGESA6PYK8',
#   'asin': 'B0002UCES4',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [0, 0],
#   'reviewText': "I didn't want to pay a lot for one of these so I guess I wasn't surprised by the quality.  It worked well enough for the first couple of weeks postpartum, though you can often see the belt under your clothing.  But then the velcro started to go, and now five weeks later it doesn't stay on at all.  My belly is going away anyway, but if you want one that lasts longer this isn't for you.",
#   'overall': 3.0,
#   'summary': 'Worked decently for a couple weeks',
#   'unixReviewTime': 1353888000,
#   'reviewTime': Timestamp('2012-11-26 00:00:00'),
#   'year': 2012,
#   'month': 11,
#   'day': 26},
#  {'reviewerID': 'AJ2FDNZ3COBFN',
#   'asin': 'B0002UCES4',
#   'reviewerName': "C'est Moi",
#   'helpful': [4, 7],
#   'reviewText': "I bought this to use immediately after giving birth. For the price it is a good value. There are much more expensive bands that do the same or less. The velcro is very strong. One thing that annoyed me is that there was always a ripple when it's closed that is visible through clothing. It wasn't that big a deal though, because I was wearing baggy tops anyway.  I now use a different one by Flexees because my stomach went down a little.",
#   'overall': 4.0,
#   'summary': 'Worked well',
#   'unixReviewTime': 1326067200,
#   'reviewTime': Timestamp('2012-01-09 00:00:00'),
#   'year': 2012,
#   'month': 1,
#   'day': 9},
#  {'reviewerID': 'A3OQ4I8U6TYCVE',
#   'asin': 'B0002UCES4',
#   'reviewerName': 'DIY Mom',
#   'helpful': [0, 3],
#   'reviewText': "I was happy to find that this was a very strong compression belt material and in a size that wasn't too large. I ordered the small despite my aversion to ordering anything in small; I normally have a 29-30 inch waist. Their sizing was true to form, I can't currently fit it around my 8 months pregnant tummy at all, so thats a good sign. The overall height seems appropriate, not too tall or too short. Its a little tough to put on by yourself; but that could be because I tried it on my husband and he is bigger than the recommended belt size.I am satisfied with this purchase and I think it will work out well to help reduce my waist size postpartum.I think this is a great accessory for mothers and everyone should get one for their postpartum months to help get back to their original shapes.",
#   'overall': 5.0,
#   'summary': 'better than I thought it would be',
#   'unixReviewTime': 1337644800,
#   'reviewTime': Timestamp('2012-05-22 00:00:00'),
#   'year': 2012,
#   'month': 5,
#   'day': 22},
#  {'reviewerID': 'A1YXY72X1ACZB8',
#   'asin': 'B0002UCES4',
#   'reviewerName': 'Mea Bowles',
#   'helpful': [0, 0],
#   'reviewText': 'I liked the belt, it was a little bothersome to wear and rode up at times.  It does a good job and when worn post partum immediately it was very effective.',
#   'overall': 4.0,
#   'summary': 'Happy with the results',
#   'unixReviewTime': 1325808000,
#   'reviewTime': Timestamp('2012-01-06 00:00:00'),
#   'year': 2012,
#   'month': 1,
#   'day': 6},
#  {'reviewerID': 'A3QUY5QP5L283S',
#   'asin': 'B0002UCES4',
#   'reviewerName': 'Shaz',
#   'helpful': [0, 0],
#   'reviewText': 'It really helped me in getting my tummy back to pre pregnancy size within 3 weeks. I wish I knew about it in my first pregnancy..now I just need to lose my tummy flab I got after my first pregnancy!',
#   'overall': 5.0,
#   'summary': 'Love it!',
#   'unixReviewTime': 1355702400,
#   'reviewTime': Timestamp('2012-12-17 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 17},
#  {'reviewerID': 'A8710RWTFG3IY',
#   'asin': 'B0002UD438',
#   'reviewerName': 'Amelia Gremelspacher',
#   'helpful': [0, 0],
#   'reviewText': 'First of all, to explain the title, I get really itchy with some metal jewelry.  This one advertises hypoallergenic, and it is hypoallergenic.  So it is also extremely comfortable.  The dial is easy to read.  Even better, I get many compliments on this watch.  My mother accused me of spending too much on a watch, which translates to a compliment in mom speech.  The mother of pearl dial has just the hint of shine.  it is easy to read and the hands are long enough that the time is clear.  ( you know how sometimes there are tiny little hands that only suggest the direction of the dial? ).  So a perfect marriage, beauty and function, and no itch.',
#   'overall': 5.0,
#   'summary': 'A perfect marriage and no itch.',
#   'unixReviewTime': 1356048000,
#   'reviewTime': Timestamp('2012-12-21 00:00:00'),
#   'year': 2012,
#   'month': 12,
#   'day': 21},
#  {'reviewerID': 'A38Z8ZXX1BPFRL',
#   'asin': 'B0002UD438',
#   'reviewerName': 'Melodie "2kidznus"',
#   'helpful': [0, 0],
#   'reviewText': 'I love this watch. It is all of the above and more. Only thing is that I received the watch with the crystals not this exact model, but still love the slim, timeless design.Highly recommend for any age as it is a sleek and classic watch.Update June 26,2012....I often get compliments on this watch from strangers. It is very comfortable to wear',
#   'overall': 5.0,
#   'summary': 'Beautiful, sleek,lightweight and comfortable',
#   'unixReviewTime': 1331856000,
#   'reviewTime': Timestamp('2012-03-16 00:00:00'),
#   'year': 2012,
#   'month': 3,
#   'day': 16},
#  {'reviewerID': 'A1XCZRFLKE9UON',
#   'asin': 'B0002UD438',
#   'reviewerName': 'Seebach311 "Seebs311"',
#   'helpful': [2, 2],
#   'reviewText': "I bought this for my wife as an anniversary present for our 11th anniversary (Traditionally-steel).  It has a sleek and elegant design butthe picture doesn't do it justice, the stainless steel is highly polished and the mother of pearl face gives off beautiful colors in changing lighting.The band is comfortable, easily adjusted and the clasp is very sturdy, I own a few Skagen's (3) and besides a couple of batteries they have never given me a problemWatch has a light thin design and the face is about the size of a nickel.",
#   'overall': 5.0,
#   'summary': 'A great bargain',
#   'unixReviewTime': 1344038400,
#   'reviewTime': Timestamp('2012-08-04 00:00:00'),
#   'year': 2012,
#   'month': 8,
#   'day': 4},
#  {'reviewerID': 'A2EKX87HLHZLIW',
#   'asin': 'B0002UNNBG',
#   'reviewerName': 'ampm247 "AnnMarie"',
#   'helpful': [0, 0],
#   'reviewText': 'i have had these ballet slippers for many years, this year i am fortunate enough to be able to order a few new pairs and as always i ADORE them! not to rough when first worn, very comfy and will last me a long time! thanks (O:also though i have a wide foot and ordered these 2 pair in wide , i didnt need to i could have used just the regualr width. the elastic ties will straighten that out for me just fine though so im keeping these.',
#   'overall': 5.0,
#   'summary': 'great as always!',
#   'unixReviewTime': 1334793600,
#   'reviewTime': Timestamp('2012-04-19 00:00:00'),
#   'year': 2012,
#   'month': 4,
#   'day': 19},
#  {'reviewerID': 'A163G9S2C825TI',
#   'asin': 'B0002UNNBG',
#   'reviewerName': 'KKL',
#   'helpful': [0, 0],
#   'reviewText': "These are good dance shoes and hold up well! However, I have a foot that is somewhat narrower than normal, and these slippers are extremely wide. I had to pull the strings for a while until I got the proper fit. But then the material from the slippers started to rub at my heel bones from the tightness. It was a little painful so I readjusted the strings to loosen them in the heel area and now the slippers fit comfortably. I did notice, however, that after using them for just one dance class, the sole started to darken significantly. It's not a big deal to me, but others might be bothered by it.",
#   'overall': 4.0,
#   'summary': 'Good slippers',
#   'unixReviewTime': 1343952000,
#   'reviewTime': Timestamp('2012-08-03 00:00:00'),
#   'year': 2012,
#   'month': 8,
#   'day': 3},
#  ...]

# %%
filename="./dataa/processedData/reviews/reviews.parquet"

df['reviewTime'] = pd.to_datetime(df['reviewTime'])
df['year'] = [row.year for row in df['reviewTime']]
df['month'] = [row.month for row in df['reviewTime']]
df['day'] = [row.day for row in df['reviewTime']]


df.to_parquet(filename, compression='gzip', partition_cols=['year', 'month', 'day'])
# reviewsDF = sqlContext.createDataFrame(df)
# reviewsDF.write.partitionBy(['year', 'month', 'day']).mode("append").parquet(filename)

# %%
# reviewsDF.to_parquet("./dataa/processedData/", root_path='reviews', compression='gzip', partition_cols=['year', 'month', 'day'])
# dataset = pq.ParquetDataset("./dataa/processedData")
# table = dataset.read(root_path='reviews')
# table
# reviewsDF.createOrReplaceTempView('reviews_reviews')
# filename=data_dir+'/decon_%s_%s.parquet'%(state,meas)

pqdf=sqlContext.read.parquet(filename)
print(pqdf.count())


sqlContext.registerDataFrameAsTable(pqdf,'reviews')
Query="SELECT * FROM reviews\n\t"
ndf = sqlContext.sql(Query)

# filename="./dataa/processedData/reviews/reviews.parquet"
# ndf.write.parquet(filename, mode='overwrite', partitionBy=['year', 'month', 'day'], compression='gzip')
# Out:
# 278677

# %%
filename = './{bucket}/{DB}/{table}'.format(
    bucket=DL.BUCKET_NAME,
    table='Clothing_Shoes_and_Jewelry_5.json.gz', 
    DB='landingZone'
)

rdd = sc.textFile(filename)

year = 2012

def parseDate(d):
    unixt = datetime.datetime.utcfromtimestamp(d['unixReviewTime'])
    d['year'] = unixt.year
    d['month'] = unixt.month
    d['day'] = unixt.day
    return d
    
reviewsRDD = rdd.map(lambda a: toJson(a)).map(lambda a: parseDate(a)).filter(lambda a: a['year'] == year)
reviewsRDD.take(5)

reviewsDF = sqlContext.createDataFrame(reviewsRDD)
filename = './{bucket}/{DB}/main_cat={category}/{table}/year={y}/'.format(
    bucket=DL.BUCKET_NAME,
    category='Clothing, Shoes & Jewelry', 
    table='reviews.parquet', 
    DB='standardizationZone',
    y = str(year)
)

reviewsDF.write.partitionBy('year', 'month', 'day').parquet(filename)
# Out:
#                                             category  \
# 0  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 1  [Clothing, Shoes & Jewelry, Luggage & Travel G...
# 2  [Clothing, Shoes & Jewelry, Luggage & Travel G...
# 3  [Clothing, Shoes & Jewelry, Luggage & Travel G...
# 4  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
#
#                                          description  \
# 0  [6" long, stretched waist measures 11 1/2" acr...
# 1  [The Hottest Bag in Town! Brand: Anello Condit...
# 2  [The Hottest Bag in Town! Brand: Anello Condit...
# 3  [The Hottest Bag in Town! Brand: Anello Condit...
# 4  [Brand New.  Hat Centre Length: adult about 8c...
#
#                                                title       brand  \
# 0  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...  Big Dreams
# 1  Japan Anello Backpack Unisex LARGE LIGHT GRAY ...      Anello
# 2  Japan Anello Backpack Unisex PINK BEIGE LARGE ...      Anello
# 3  Japan Anello Backpack Unisex BLACK LARGE PU LE...      Anello
# 4  bettyhome Unisex Adult Winter Spring Thicken C...   bettyhome
#
#                                              feature  \
# 0  [3 layers of tulle, 6" long, stretched waist m...
# 1  [Polyester Canvas Waterproof, Imported, Size: ...
# 2  [PU Leather, Imported, Size: Large PU Leather ...
# 3  [PU Leather, Imported, Size: Large PU Leather ...
# 4  [Imported, Plush,Cotton, Polyester, Lovely for...
#
#                                  rank               date        asin  \
# 0  19,963,069inClothing,ShoesJewelry(  5 star5 star (0%)  0000037214
# 1   4,537,420inClothing,ShoesJewelry(             5 star  0201377179
# 2   3,994,472inClothing,ShoesJewelry(             5 star  0204444454
# 3     635,761inClothing,ShoesJewelry(             5 star  0204444403
# 4   5,061,041inClothing,ShoesJewelry(  5 star5 star (0%)  0206313535
#
#                                                image  \
# 0                                                NaN
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                            also_view   price  fit also_buy  \
# 0                                                NaN     NaN  NaN      NaN
# 1                                                NaN     NaN  NaN      NaN
# 2  [B07CJF5HLR, B01EBI8UH6, B01N1LR908, B074M4QKG...  $70.00  NaN      NaN
# 3  [B01DLVYOPG, B07CJF5HLR, B01MSS59Y6, B071YBC1J...  $65.99  NaN      NaN
# 4  [B00VGT93YS, B07FTY87LM, B01IKVOY8E, B01GF6C6F...  $18.99  NaN      NaN
#
#   main_cat tech1 details similar_item tech2
# 0      NaN   NaN     NaN          NaN   NaN
# 1      NaN   NaN     NaN          NaN   NaN
# 2      NaN   NaN     NaN          NaN   NaN
# 3      NaN   NaN     NaN          NaN   NaN
# 4      NaN   NaN     NaN          NaN   NaN

# %%
def packArray(a):
    """
    pack a numpy array into a bytearray that can be stored as a single 
    field in a spark DataFrame

    :param a: a numpy ndarray 
    :returns: a bytearray
    :rtype:

    """
    if type(a)!=np.ndarray:
        raise Exception("input to packArray should be numpy.ndarray. It is instead "+str(type(a)))
    return bytearray(a.tobytes())

packed = packArray(metaDF['category'])
packed
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-461-1eb77ab1c8f8> in <module>
#      13     return bytearray(a.tobytes())
#      14
# ---> 15 packed = packArray(metaDF['category'])
#      16 packed
#
# <ipython-input-461-1eb77ab1c8f8> in packArray(a)
#      10     """
#      11     if type(a)!=np.ndarray:
# ---> 12         raise Exception("input to packArray should be numpy.ndarray. It is instead "+str(type(a)))
#      13     return bytearray(a.tobytes())
#      14
#
# Exception: input to packArray should be numpy.ndarray. It is instead <class 'pandas.core.series.Series'>

# %%
# %%time
# !aws s3 cp './data/standardizationZone/' 's3://dse-cohort5-group1/data-lake-standardization-zone/metaData.parquet' --recursive --profile=ucsd --region=us-east-1

# %%
# from pyspark import SparkContext
# from pyspark.sql import *
# sc = SparkContext(master="local[3]")
# sqlContext = SQLContext(sc)
# dd.groupby([]count()
dd.columns = ['deviceId', 'category']
ddg = dd.groupby(['category']).count()
ddg2 = ddg[ddg['deviceId'].sort_values(ascending=False)/ddg['deviceId'].max() > .1]

# filt = ddg['deviceId'].sort()
ddg2.plot.barh()
# Out:
# /Users/justin.shamoun/anaconda/envs/dse_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# Out:
# category
# Clothing, Shoes & Jewelry                               True
# Women                                                   True
# Men                                                    False
# Shoes                                                  False
# Clothing                                               False
#                                                        ...
# Officially Licensed Big Bang Theory Merchandise        False
# Officially Licensed Big Bang Theory T-Shirt            False
# Officially Licensed Billy Idol Merchandise             False
# Officially Licensed Black Label Society Merchandise    False
# Lace lock for added style and security                 False
# Name: deviceId, Length: 383661, dtype: bool

# %%
def getTables(Data_dir="./dataa/processedData"):
    Tables = {}
    filenames = glob(Data_dir + "/*.parquet.gzip")
    i = 0
    for fname in filenames:
        print(fname)
        dataset = pq.ParquetDataset(fname)
        Tables[i] = dataset.read()
        i += 1
    return Tables


d = getTables()
d
df=sqlContext.read.parquet(data_dir/NY.parquet)
# Out:
# ./dataa/processedData/reviews_2012.parquet.gzip
# ./dataa/processedData/reviews_2011.parquet.gzip
# {0: pyarrow.Table
#  reviewerID: string
#  asin: string
#  reviewerName: string
#  helpful: list<item: int64>
#    child 0, item: int64
#  reviewText: string
#  overall: double
#  summary: string
#  unixReviewTime: int64
#  reviewTime: timestamp[ms]
#  year: dictionary<values=int64, indices=int32, ordered=0>
#  month: dictionary<values=int64, indices=int32, ordered=0>
#  day: dictionary<values=int64, indices=int32, ordered=0>
#  metadata
#  --------
#  OrderedDict([(b'pandas',
#                b'{"index_columns": [], "column_indexes": [], "columns": [{"na'
#                b'me": "reviewerID", "field_name": "reviewerID", "pandas_type"'
#                b': "unicode", "numpy_type": "object", "metadata": null}, {"na'
#                b'me": "asin", "field_name": "asin", "pandas_type": "unicode",'
#                b' "numpy_type": "object", "metadata": null}, {"name": "review'
#                b'erName", "field_name": "reviewerName", "pandas_type": "unico'
#                b'de", "numpy_type": "object", "metadata": null}, {"name": "he'
#                b'lpful", "field_name": "helpful", "pandas_type": "list[int64]'
#                b'", "numpy_type": "object", "metadata": null}, {"name": "revi'
#                b'ewText", "field_name": "reviewText", "pandas_type": "unicode'
#                b'", "numpy_type": "object", "metadata": null}, {"name": "over'
#                b'all", "field_name": "overall", "pandas_type": "float64", "nu'
#                b'mpy_type": "float64", "metadata": null}, {"name": "summary",'
#                b' "field_name": "summary", "pandas_type": "unicode", "numpy_t'
#                b'ype": "object", "metadata": null}, {"name": "unixReviewTime"'
#                b', "field_name": "unixReviewTime", "pandas_type": "int64", "n'
#                b'umpy_type": "int64", "metadata": null}, {"name": "reviewTime'
#                b'", "field_name": "reviewTime", "pandas_type": "datetime", "n'
#                b'umpy_type": "datetime64[ns]", "metadata": null}], "creator":'
#                b' {"library": "pyarrow", "version": "0.15.1"}, "pandas_versio'
#                b'n": "0.25.2"}')]), 1: pyarrow.Table
#  reviewerID: string
#  asin: string
#  reviewerName: string
#  helpful: list<item: int64>
#    child 0, item: int64
#  reviewText: string
#  overall: double
#  summary: string
#  unixReviewTime: int64
#  reviewTime: timestamp[ms]
#  year: dictionary<values=int64, indices=int32, ordered=0>
#  month: dictionary<values=int64, indices=int32, ordered=0>
#  day: dictionary<values=int64, indices=int32, ordered=0>
#  metadata
#  --------
#  OrderedDict([(b'pandas',
#                b'{"index_columns": [], "column_indexes": [], "columns": [{"na'
#                b'me": "reviewerID", "field_name": "reviewerID", "pandas_type"'
#                b': "unicode", "numpy_type": "object", "metadata": null}, {"na'
#                b'me": "asin", "field_name": "asin", "pandas_type": "unicode",'
#                b' "numpy_type": "object", "metadata": null}, {"name": "review'
#                b'erName", "field_name": "reviewerName", "pandas_type": "unico'
#                b'de", "numpy_type": "object", "metadata": null}, {"name": "he'
#                b'lpful", "field_name": "helpful", "pandas_type": "list[int64]'
#                b'", "numpy_type": "object", "metadata": null}, {"name": "revi'
#                b'ewText", "field_name": "reviewText", "pandas_type": "unicode'
#                b'", "numpy_type": "object", "metadata": null}, {"name": "over'
#                b'all", "field_name": "overall", "pandas_type": "float64", "nu'
#                b'mpy_type": "float64", "metadata": null}, {"name": "summary",'
#                b' "field_name": "summary", "pandas_type": "unicode", "numpy_t'
#                b'ype": "object", "metadata": null}, {"name": "unixReviewTime"'
#                b', "field_name": "unixReviewTime", "pandas_type": "int64", "n'
#                b'umpy_type": "int64", "metadata": null}, {"name": "reviewTime'
#                b'", "field_name": "reviewTime", "pandas_type": "datetime", "n'
#                b'umpy_type": "datetime64[ns]", "metadata": null}], "creator":'
#                b' {"library": "pyarrow", "version": "0.15.1"}, "pandas_versio'
#                b'n": "0.25.2"}')])}

# %%
d[1]['reviewTime']
# Out:
# <pyarrow.lib.ChunkedArray object at 0x40ec357c8>
# [
#   [
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000,
#     2011-01-01 00:00:00.000
#   ],
#   [
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     ...
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000,
#     2011-01-10 00:00:00.000
#   ],
#   [
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     ...
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000,
#     2011-01-11 00:00:00.000
#   ],
#   [
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     ...
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000,
#     2011-01-12 00:00:00.000
#   ],
#   [
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     ...
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000,
#     2011-01-13 00:00:00.000
#   ],
#   [
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000,
#     2011-01-14 00:00:00.000
#   ],
#   [
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000,
#     2011-01-15 00:00:00.000
#   ],
#   [
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000,
#     2011-01-16 00:00:00.000
#   ],
#   [
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     ...
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000,
#     2011-01-17 00:00:00.000
#   ],
#   [
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000,
#     2011-01-18 00:00:00.000
#   ],
# ...
#   [
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     ...
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000,
#     2011-09-28 00:00:00.000
#   ],
#   [
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     ...
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000,
#     2011-09-29 00:00:00.000
#   ],
#   [
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000,
#     2011-09-03 00:00:00.000
#   ],
#   [
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     ...
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000,
#     2011-09-30 00:00:00.000
#   ],
#   [
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000,
#     2011-09-04 00:00:00.000
#   ],
#   [
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     ...
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000,
#     2011-09-05 00:00:00.000
#   ],
#   [
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     ...
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000,
#     2011-09-06 00:00:00.000
#   ],
#   [
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     ...
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000,
#     2011-09-07 00:00:00.000
#   ],
#   [
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     ...
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000,
#     2011-09-08 00:00:00.000
#   ],
#   [
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     ...
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000,
#     2011-09-09 00:00:00.000
#   ]
# ]

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime'],
#       dtype='object')

# %%
import pickle
df.to_pickle("./data/{}.pkl".format('all'))
TickerInfo=D['TickerInfo']
        Tickers=D['Tickers']
reviewsDF
metaDF2
def getTables(Data_dir='./data'):
    Tables = {}
# #     exclude = ['2012']
# #     tfid_result_df.to_pickle("./preped_{}_max_feature{}.pkl".format('tfid_result_df', '100'))
    filenames = glob(Data_dir + "/r.pkl")
    
    for fname in filenames:
    D=pickle.load(open(fname,'rb'))
        TickerInfo=D['TickerInfo']
        Tickers=D['Tickers']

        Tables[D]
        return D


d = getTables()
d
# Out:
#             reviewerID        asin                              reviewerName  \
# 0       A1KLRMWW2FWPL4  0000031887               Amazon Customer "cameramom"
# 1       A2G5TCU2WDFZ65  0000031887                           Amazon Customer
# 2       A1RLQXYNCMWRWN  0000031887                                    Carola
# 3        A8U3FAMSJVHS5  0000031887                                   Caromcg
# 4       A3GEOILWLK86XM  0000031887                                        CJ
# ...                ...         ...                                       ...
# 278672  A2DG63DN704LOI  B00KKXCJQU                                    ESlayd
# 278673  A1EVV74UQYVKRY  B00KKXCJQU                                   K. Groh
# 278674  A1UQBFCERIP7VJ  B00KKXCJQU                            Margaret Picky
# 278675  A22CW0ZHY3NJH8  B00KKXCJQU                                    Noname
# 278676  A30VWT3R25QAVD  B00KKXCJQU  THE-DEADLY-DOG "Living and Loving Life."
#
#        helpful                                         reviewText  overall  \
# 0       [0, 0]  This is a great tutu and at a really great pri...      5.0
# 1       [0, 0]  I bought this for my 4 yr old daughter for dan...      5.0
# 2       [0, 0]  What can I say... my daughters have it in oran...      5.0
# 3       [0, 0]  We bought several tutus at once, and they are ...      5.0
# 4       [0, 0]  Thank you Halo Heaven great product for Little...      5.0
# ...        ...                                                ...      ...
# 278672  [0, 1]  I don't normally go ga-ga over a product very ...      5.0
# 278673  [0, 0]  I've been traveling back and forth to England ...      5.0
# 278674  [1, 1]  These are very nice packing cubes and the 18 x...      5.0
# 278675  [2, 2]  I am on vacation with my family of four and th...      5.0
# 278676  [0, 1]  When I signed up to receive a free set of Shac...      5.0
#
#                                                   summary  unixReviewTime  \
# 0                           Great tutu-  not cheaply made      1297468800
# 1                                             Very Cute!!      1358553600
# 2                                I have buy more than one      1357257600
# 3                                        Adorable, Sturdy      1398556800
# 4                                 Grammy's Angels Love it      1394841600
# ...                                                   ...             ...
# 278672     These have literally changed the way I travel!      1403568000
# 278673                       Wonderful for Better Packing      1403740800
# 278674               Convenient, lightweight, and durable      1402185600
# 278675                   Holds Up Well In Real World Test      1404691200
# 278676  Don't Travel? Still Way too Useful for 'Averag...      1403481600
#
#        reviewTime  year  month  day
# 0      2011-02-12  2011      2   12
# 1      2013-01-19  2013      1   19
# 2      2013-01-04  2013      1    4
# 3      2014-04-27  2014      4   27
# 4      2014-03-15  2014      3   15
# ...           ...   ...    ...  ...
# 278672 2014-06-24  2014      6   24
# 278673 2014-06-26  2014      6   26
# 278674 2014-06-08  2014      6    8
# 278675 2014-07-07  2014      7    7
# 278676 2014-06-23  2014      6   23
#
# [278677 rows x 12 columns]

# %%
def train_test_features(df):
    X = df.drop(['helpful_rate'], axis=1)
    y = df[['helpful_rate']]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    filename = 'X_train'
    X_train.to_pickle("./preped_{}_df_test.pkl".format('X_train'))
    X_test.to_pickle("./preped_{}_df_test.pkl".format('X_test'))
    y_train.to_pickle("./preped_{}_df_test.pkl".format('y_train'))
    y_test.to_pickle("./preped_{}_df_test.pkl".format('y_test'))


    return X_train, X_test, y_train, y_test

# %%
df.to_parquet('./data/data/reviews.parquet.gzip', compression='gzip', partition_cols=['asin'])

# %%
sample_path = './data/sample_data_1M.json'
df_sample = getDF(PATH)
df_sample.head()
# Out:
#        reviewerID        asin                 reviewerName helpful  \
# 0  A1KLRMWW2FWPL4  0000031887  Amazon Customer "cameramom"  [0, 0]
# 1  A2G5TCU2WDFZ65  0000031887              Amazon Customer  [0, 0]
# 2  A1RLQXYNCMWRWN  0000031887                       Carola  [0, 0]
# 3   A8U3FAMSJVHS5  0000031887                      Caromcg  [0, 0]
# 4  A3GEOILWLK86XM  0000031887                           CJ  [0, 0]
#
#                                           reviewText  overall  \
# 0  This is a great tutu and at a really great pri...      5.0
# 1  I bought this for my 4 yr old daughter for dan...      5.0
# 2  What can I say... my daughters have it in oran...      5.0
# 3  We bought several tutus at once, and they are ...      5.0
# 4  Thank you Halo Heaven great product for Little...      5.0
#
#                          summary  unixReviewTime   reviewTime
# 0  Great tutu-  not cheaply made      1297468800  02 12, 2011
# 1                    Very Cute!!      1358553600  01 19, 2013
# 2       I have buy more than one      1357257600   01 4, 2013
# 3               Adorable, Sturdy      1398556800  04 27, 2014
# 4        Grammy's Angels Love it      1394841600  03 15, 2014

# %%
df_sample.describe()
# Out:
#              overall  unixReviewTime
# count  278677.000000    2.786770e+05
# mean        4.245133    1.374197e+09
# std         1.103747    2.904510e+07
# min         1.000000    1.048896e+09
# 25%         4.000000    1.362787e+09
# 50%         5.000000    1.382141e+09
# 75%         5.000000    1.393200e+09
# max         5.000000    1.406074e+09

# %%
def data_preprocessing(dataframe):
    dataframe['n_categories'] = dataframe['categories'].str.len()
    dataframe['item_id'] = dataframe['itemID'].factorize()[0]
    dataframe['user_id'] = dataframe['reviewerID'].factorize()[0]
    dataframe['category_id'] = dataframe['categoryID'].factorize()[0]

    category_id_df = dataframe[['item_id', 'category_id']].drop_duplicates().sort_values('category_id')
    category_to_id = dict(category_id_df.values)

    id_to_category = dict(category_id_df[['category_id', 'item_id']].values)
    dataframe["textlength"] = dataframe['reviewText'].str.len()
    dummies = pd.get_dummies(dataframe['categoryID']).rename(columns=lambda x: 'categoryID_'+str(x))
    dataframe = pd.concat([dataframe, dummies], axis=1)
    helpful = pd.DataFrame.from_dict(dict(dataframe['helpful'])).T
    dataframe = pd.concat([dataframe, helpful], axis=1)
    dataframe['reviewTime'] = pd.to_datetime(dataframe['reviewTime'])
    
    dataframe['helpful_rate'] = dataframe['nHelpful']/dataframe['outOf']
    dataframe['outOf'] = dataframe['outOf']
    dataframe['helpful_rate'].fillna(0, inplace=True)
    user_helpful = dataframe.groupby(['reviewerID'])['helpful_rate'].mean()
    categoryPriceMeans = dataframe.groupby(['categoryID'])['price'].mean()
    dataframe['user_helpful'] = user_helpful
    dataframe['user_helpful'].fillna(user_helpful, inplace=True)
    dataframe['price'] = dataframe.groupby(['categoryID'])['price'].mean()
    dataframe['price'].fillna(categoryPriceMeans, inplace=True)
  
    return dataframe

# %%
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

# %%
usersDF = df.groupby(['reviewerID'])['reviewText'].count()
usersDF.head()
# Out:
# reviewerID
# A001114613O3F18Q5NVR6    7
# A00146182PNM90WNNAZ5Q    7
# A00165422B2GAUE3EL6Z0    6
# A00338282E99B8OR2JYTZ    5
# A00354001GE099Q1FL0TU    5
# Name: reviewText, dtype: int64

# %%
usersDF.hist()

# %%
# filename=DATA_DIR+FILE_NAME
# df=sqlContext.read.json(filename)

productDF = df.groupby(['asin'])['reviewText'].count()
productDF.hist()

# df=sqlContext.read.parquet(data_dir/NY.parquet)

# %%
df.show(5)
# Out:
# +--------+--------------------+----------+----------+--------------------+-----------------+--------------------+-------+--------------------+----+--------------------+--------+------+--------------------+------------+-----+-----+--------------------+
# |also_buy|           also_view|      asin|     brand|            category|             date|         description|details|             feature| fit|               image|main_cat| price|                rank|similar_item|tech1|tech2|               title|
# +--------+--------------------+----------+----------+--------------------+-----------------+--------------------+-------+--------------------+----+--------------------+--------+------+--------------------+------------+-----+-----+--------------------+
# |    null|                null|0000037214|Big Dreams|[Clothing, Shoes ...|5 star5 star (0%)|[6" long, stretch...|   null|[3 layers of tull...|null|                null|    null|  null|19,963,069inCloth...|        null| null| null|Purple Sequin Tin...|
# |    null|                null|0201377179|    Anello|[Clothing, Shoes ...|           5 star|[The Hottest Bag ...|   null|[Polyester Canvas...|null|[https://images-n...|    null|  null|4,537,420inClothi...|        null| null| null|Japan Anello Back...|
# |    null|[B07CJF5HLR, B01E...|0204444454|    Anello|[Clothing, Shoes ...|           5 star|[The Hottest Bag ...|   null|[PU Leather, Impo...|null|[https://images-n...|    null|$70.00|3,994,472inClothi...|        null| null| null|Japan Anello Back...|
# |    null|[B01DLVYOPG, B07C...|0204444403|    Anello|[Clothing, Shoes ...|           5 star|[The Hottest Bag ...|   null|[PU Leather, Impo...|null|[https://images-n...|    null|$65.99|635,761inClothing...|        null| null| null|Japan Anello Back...|
# |    null|[B00VGT93YS, B07F...|0206313535| bettyhome|[Clothing, Shoes ...|5 star5 star (0%)|[Brand New.  Hat ...|   null|[Imported, Plush,...|null|[https://images-n...|    null|$18.99|5,061,041inClothi...|        null| null| null|bettyhome Unisex ...|
# +--------+--------------------+----------+----------+--------------------+-----------------+--------------------+-------+--------------------+----+--------------------+--------+------+--------------------+------------+-----+-----+--------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- also_buy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- also_view: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- asin: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date: string (nullable = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- details: string (nullable = true)
#  |-- feature: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fit: string (nullable = true)
#  |-- image: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- main_cat: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- similar_item: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- asin: string (nullable = true)
#  |    |    |-- features: struct (nullable = true)
#  |    |    |    |-- Additional Features: string (nullable = true)
#  |    |    |    |-- Age Range Description: string (nullable = true)
#  |    |    |    |-- Apparel Closure Type: string (nullable = true)
#  |    |    |    |-- Are Batteries Included: string (nullable = true)
#  |    |    |    |-- Are Batteries Required: string (nullable = true)
#  |    |    |    |-- Are batteries included?: string (nullable = true)
#  |    |    |    |-- Aspect Ratio: string (nullable = true)
#  |    |    |    |-- Back Finding: string (nullable = true)
#  |    |    |    |-- Band Color: string (nullable = true)
#  |    |    |    |-- Band Material Type: string (nullable = true)
#  |    |    |    |-- Band Size: string (nullable = true)
#  |    |    |    |-- Band Width: string (nullable = true)
#  |    |    |    |-- Batteries are Included: string (nullable = true)
#  |    |    |    |-- Boot Shaft Height: string (nullable = true)
#  |    |    |    |-- Bottom Style: string (nullable = true)
#  |    |    |    |-- Cap: string (nullable = true)
#  |    |    |    |-- Case Diameter: string (nullable = true)
#  |    |    |    |-- Case Material Type: string (nullable = true)
#  |    |    |    |-- Case Thickness: string (nullable = true)
#  |    |    |    |-- Chain Type: string (nullable = true)
#  |    |    |    |-- Chest Size: string (nullable = true)
#  |    |    |    |-- Clasp Type: string (nullable = true)
#  |    |    |    |-- Closure Type: string (nullable = true)
#  |    |    |    |-- Color: string (nullable = true)
#  |    |    |    |-- Compatible Phone Models: string (nullable = true)
#  |    |    |    |-- Crystal: string (nullable = true)
#  |    |    |    |-- Customer Rating: string (nullable = true)
#  |    |    |    |-- Customizable Template Name: string (nullable = true)
#  |    |    |    |-- Design: string (nullable = true)
#  |    |    |    |-- Dial Color: string (nullable = true)
#  |    |    |    |-- Dial Window Material Type: string (nullable = true)
#  |    |    |    |-- Dimensions Source Size Name: string (nullable = true)
#  |    |    |    |-- Display: string (nullable = true)
#  |    |    |    |-- Display Resolution Maximum: string (nullable = true)
#  |    |    |    |-- Display Type: string (nullable = true)
#  |    |    |    |-- Enclosure Material: string (nullable = true)
#  |    |    |    |-- Fabric Type: string (nullable = true)
#  |    |    |    |-- Finish Types: string (nullable = true)
#  |    |    |    |-- Fit Type: string (nullable = true)
#  |    |    |    |-- Headphone Fit: string (nullable = true)
#  |    |    |    |-- Heel: string (nullable = true)
#  |    |    |    |-- Heel Type: string (nullable = true)
#  |    |    |    |-- Height Map: string (nullable = true)
#  |    |    |    |-- Is Assembly Required: string (nullable = true)
#  |    |    |    |-- Is Assembly Required?: string (nullable = true)
#  |    |    |    |-- Item Dimensions: string (nullable = true)
#  |    |    |    |-- Item Weight: string (nullable = true)
#  |    |    |    |-- League Name: string (nullable = true)
#  |    |    |    |-- Light Source: string (nullable = true)
#  |    |    |    |-- Light Source Type: string (nullable = true)
#  |    |    |    |-- Lining Description: string (nullable = true)
#  |    |    |    |-- Lithium Battery Packaging: string (nullable = true)
#  |    |    |    |-- Material: string (nullable = true)
#  |    |    |    |-- Material Fabric: string (nullable = true)
#  |    |    |    |-- Material Type: string (nullable = true)
#  |    |    |    |-- Metal Stamp: string (nullable = true)
#  |    |    |    |-- Metal Type: string (nullable = true)
#  |    |    |    |-- Model Year: string (nullable = true)
#  |    |    |    |-- Neck Style: string (nullable = true)
#  |    |    |    |-- Number of Items: string (nullable = true)
#  |    |    |    |-- Number of Pieces: string (nullable = true)
#  |    |    |    |-- Operating System: string (nullable = true)
#  |    |    |    |-- Pattern: string (nullable = true)
#  |    |    |    |-- Pattern Style: string (nullable = true)
#  |    |    |    |-- Platform Height: string (nullable = true)
#  |    |    |    |-- Power Source: string (nullable = true)
#  |    |    |    |-- Price: string (nullable = true)
#  |    |    |    |-- Primary Stone Gem Type: string (nullable = true)
#  |    |    |    |-- Product Care Instructions: string (nullable = true)
#  |    |    |    |-- Screen Size: string (nullable = true)
#  |    |    |    |-- Setting Type: string (nullable = true)
#  |    |    |    |-- Shaft Height: string (nullable = true)
#  |    |    |    |-- Shape: string (nullable = true)
#  |    |    |    |-- Shipping: string (nullable = true)
#  |    |    |    |-- Shoe Height Map: string (nullable = true)
#  |    |    |    |-- Shoe Size: string (nullable = true)
#  |    |    |    |-- Shoe Size System: string (nullable = true)
#  |    |    |    |-- Shoe Width: string (nullable = true)
#  |    |    |    |-- Size: string (nullable = true)
#  |    |    |    |-- Size Map: string (nullable = true)
#  |    |    |    |-- Sleeve Type: string (nullable = true)
#  |    |    |    |-- Sold By: string (nullable = true)
#  |    |    |    |-- Sole Material: string (nullable = true)
#  |    |    |    |-- Special Features: string (nullable = true)
#  |    |    |    |-- Special Size: string (nullable = true)
#  |    |    |    |-- Special Size Type: string (nullable = true)
#  |    |    |    |-- Sport Type: string (nullable = true)
#  |    |    |    |-- Stone Creation Method: string (nullable = true)
#  |    |    |    |-- Stone Shape: string (nullable = true)
#  |    |    |    |-- Strap Type: string (nullable = true)
#  |    |    |    |-- Style: string (nullable = true)
#  |    |    |    |-- Style Name: string (nullable = true)
#  |    |    |    |-- Style Number: string (nullable = true)
#  |    |    |    |-- Subject Character: string (nullable = true)
#  |    |    |    |-- Supported Application: string (nullable = true)
#  |    |    |    |-- Toe Style: string (nullable = true)
#  |    |    |    |-- Top Style: string (nullable = true)
#  |    |    |    |-- Total Metal Weight: string (nullable = true)
#  |    |    |    |-- Waist Size: string (nullable = true)
#  |    |    |    |-- Watch Movement Type: string (nullable = true)
#  |    |    |    |-- Water Resistance Depth: string (nullable = true)
#  |    |    |    |-- Water Resistance Level: string (nullable = true)
#  |    |    |    |-- character: string (nullable = true)
#  |    |    |    |-- lining-description: string (nullable = true)
#  |    |    |    |-- material-fabric: string (nullable = true)
#  |    |    |    |-- model-year: string (nullable = true)
#  |    |    |    |-- size: string (nullable = true)
#  |    |    |    |-- top-style: string (nullable = true)
#  |    |    |-- href: string (nullable = true)
#  |    |    |-- img: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- tech1: struct (nullable = true)
#  |    |-- ABPA Partslink Number: string (nullable = true)
#  |    |-- Assembled Depth: string (nullable = true)
#  |    |-- Assembled Diameter: string (nullable = true)
#  |    |-- Assembled Height: string (nullable = true)
#  |    |-- Assembled Length: string (nullable = true)
#  |    |-- Assembled Width: string (nullable = true)
#  |    |-- Average Battery Life: string (nullable = true)
#  |    |-- Backing: string (nullable = true)
#  |    |-- Batteries: string (nullable = true)
#  |    |-- Batteries Included?: string (nullable = true)
#  |    |-- Batteries Required?: string (nullable = true)
#  |    |-- Battery Cell Type: string (nullable = true)
#  |    |-- Binding Edge: string (nullable = true)
#  |    |-- Blade Edge: string (nullable = true)
#  |    |-- Blade Length: string (nullable = true)
#  |    |-- Brand: string (nullable = true)
#  |    |-- Brand Name: string (nullable = true)
#  |    |-- Brightness Rating: string (nullable = true)
#  |    |-- CAPA Certified: string (nullable = true)
#  |    |-- California residents: string (nullable = true)
#  |    |-- Capacity: string (nullable = true)
#  |    |-- Card Description: string (nullable = true)
#  |    |-- Caster/Glide/Wheel Type: string (nullable = true)
#  |    |-- Certification: string (nullable = true)
#  |    |-- Closure: string (nullable = true)
#  |    |-- Coating: string (nullable = true)
#  |    |-- Color: string (nullable = true)
#  |    |-- Color Name: string (nullable = true)
#  |    |-- Construction: string (nullable = true)
#  |    |-- Cover Included: string (nullable = true)
#  |    |-- Cover Material: string (nullable = true)
#  |    |-- Diameter of Lampshade: string (nullable = true)
#  |    |-- Discontinued by manufacturer: string (nullable = true)
#  |    |-- Display Style: string (nullable = true)
#  |    |-- Expansion: string (nullable = true)
#  |    |-- Exterior: string (nullable = true)
#  |    |-- Fastener Capacity: string (nullable = true)
#  |    |-- Fastener Type: string (nullable = true)
#  |    |-- Finish: string (nullable = true)
#  |    |-- Fixture Features: string (nullable = true)
#  |    |-- Folded Knife Size: string (nullable = true)
#  |    |-- Folding: string (nullable = true)
#  |    |-- Form Size: string (nullable = true)
#  |    |-- Grade: string (nullable = true)
#  |    |-- Graphics Card Ram Size: string (nullable = true)
#  |    |-- Grit Description: string (nullable = true)
#  |    |-- Grit Rating: string (nullable = true)
#  |    |-- Handle: string (nullable = true)
#  |    |-- Handle Material: string (nullable = true)
#  |    |-- Hard Drive: string (nullable = true)
#  |    |-- Hardware Platform: string (nullable = true)
#  |    |-- Horsepower: string (nullable = true)
#  |    |-- Included Components: string (nullable = true)
#  |    |-- Ink Color: string (nullable = true)
#  |    |-- Installation Method: string (nullable = true)
#  |    |-- Item Dimensions  L x W x H: string (nullable = true)
#  |    |-- Item Display Height: string (nullable = true)
#  |    |-- Item Display dimensions L x W x H: string (nullable = true)
#  |    |-- Item Package Quantity: string (nullable = true)
#  |    |-- Item Weight: string (nullable = true)
#  |    |-- Item model number: string (nullable = true)
#  |    |-- Lift Type: string (nullable = true)
#  |    |-- Light Direction: string (nullable = true)
#  |    |-- Line Size: string (nullable = true)
#  |    |-- Locking: string (nullable = true)
#  |    |-- Luminous Flux: string (nullable = true)
#  |    |-- Manufacturer Part Number: string (nullable = true)
#  |    |-- Material: string (nullable = true)
#  |    |-- Material Type: string (nullable = true)
#  |    |-- Max Screen Resolution: string (nullable = true)
#  |    |-- Measurement System: string (nullable = true)
#  |    |-- Mirror Adjustment: string (nullable = true)
#  |    |-- Model: string (nullable = true)
#  |    |-- Model Info: string (nullable = true)
#  |    |-- National Stock Number: string (nullable = true)
#  |    |-- Number Of Pieces: string (nullable = true)
#  |    |-- Number of Fasteners: string (nullable = true)
#  |    |-- Number of Handles: string (nullable = true)
#  |    |-- Number of Items: string (nullable = true)
#  |    |-- Number of Lights: string (nullable = true)
#  |    |-- Number of USB 3.0 Ports: string (nullable = true)
#  |    |-- OEM Part Number: string (nullable = true)
#  |    |-- Package Dimensions: string (nullable = true)
#  |    |-- Paper Finish: string (nullable = true)
#  |    |-- Paper Weight: string (nullable = true)
#  |    |-- Part Number: string (nullable = true)
#  |    |-- Pattern: string (nullable = true)
#  |    |-- Plug Profile: string (nullable = true)
#  |    |-- Point Type: string (nullable = true)
#  |    |-- Position: string (nullable = true)
#  |    |-- Post-Consumer Recycled Content Percentage: string (nullable = true)
#  |    |-- Power Source: string (nullable = true)
#  |    |-- Pre-printed: string (nullable = true)
#  |    |-- Processor: string (nullable = true)
#  |    |-- Product Dimensions: string (nullable = true)
#  |    |-- RAM: string (nullable = true)
#  |    |-- Rim Diameter: string (nullable = true)
#  |    |-- Safety Rating: string (nullable = true)
#  |    |-- Screen Size: string (nullable = true)
#  |    |-- Series: string (nullable = true)
#  |    |-- Shade Material: string (nullable = true)
#  |    |-- Shape: string (nullable = true)
#  |    |-- Sheet Size: string (nullable = true)
#  |    |-- Size: string (nullable = true)
#  |    |-- Special Features: string (nullable = true)
#  |    |-- Specific Uses: string (nullable = true)
#  |    |-- Specification Met: string (nullable = true)
#  |    |-- Speed Rating: string (nullable = true)
#  |    |-- Strength: string (nullable = true)
#  |    |-- Style: string (nullable = true)
#  |    |-- Switch Style: string (nullable = true)
#  |    |-- Tab Color: string (nullable = true)
#  |    |-- Tab Material: string (nullable = true)
#  |    |-- Tab Position: string (nullable = true)
#  |    |-- Total Recycled Content Percentage: string (nullable = true)
#  |    |-- Type of Bulb: string (nullable = true)
#  |    |-- UV Protection: string (nullable = true)
#  |    |-- Usage: string (nullable = true)
#  |    |-- Vehicle Service Type: string (nullable = true)
#  |    |-- Voltage: string (nullable = true)
#  |    |-- Volume: string (nullable = true)
#  |    |-- Warranty Description: string (nullable = true)
#  |    |-- Wattage: string (nullable = true)
#  |    |-- Weight: string (nullable = true)
#  |    |-- Whiteness: string (nullable = true)
#  |    |-- Wireless Remote: string (nullable = true)
#  |-- tech2: struct (nullable = true)
#  |    |-- Audio-out Ports (#): string (nullable = true)
#  |    |-- Brand Name: string (nullable = true)
#  |    |-- California residents: string (nullable = true)
#  |    |-- Color: string (nullable = true)
#  |    |-- Computer Memory Type: string (nullable = true)
#  |    |-- Flash Memory Size: string (nullable = true)
#  |    |-- Hard Drive Interface: string (nullable = true)
#  |    |-- Hard Drive Rotational Speed: string (nullable = true)
#  |    |-- Hardware Platform: string (nullable = true)
#  |    |-- Item Dimensions  L x W x H: string (nullable = true)
#  |    |-- Item Weight: string (nullable = true)
#  |    |-- Item model number: string (nullable = true)
#  |    |-- Operating System: string (nullable = true)
#  |    |-- Package Dimensions: string (nullable = true)
#  |    |-- Processor Brand: string (nullable = true)
#  |    |-- Processor Count: string (nullable = true)
#  |    |-- Product Dimensions: string (nullable = true)
#  |    |-- Series: string (nullable = true)
#  |-- title: string (nullable = true)

# %%
main_cat.show()
# Out:
# +--------------------+
# |            main_cat|
# +--------------------+
# |       Entertainment|
# |           Computers|
# |     All Electronics|
# |    GPS & Navigation|
# |Home Audio & Theater|
# |        Pet Supplies|
# |                null|
# |        Toys & Games|
# |                Baby|
# |   Sports & Outdoors|
# |             Grocery|
# |         Video Games|
# |   Collectible Coins|
# |          Automotive|
# |       Luxury Beauty|
# |               Books|
# |         Amazon Home|
# |Industrial & Scie...|
# |Health & Personal...|
# |Cell Phones & Acc...|
# +--------------------+
# only showing top 20 rows

# %%
df.groupBy('main_cat').count().show()
# Out:
# +--------------------+-------+
# |            main_cat|  count|
# +--------------------+-------+
# |       Entertainment|     31|
# |           Computers|   1155|
# |     All Electronics|    461|
# |    GPS & Navigation|      3|
# |Home Audio & Theater|    163|
# |        Pet Supplies|     81|
# |        Toys & Games|  24327|
# |                null|2471831|
# |                Baby|   7213|
# |   Sports & Outdoors| 116135|
# |             Grocery|    147|
# |         Video Games|    168|
# |   Collectible Coins|      2|
# |          Automotive|   3716|
# |       Luxury Beauty|      2|
# |               Books|  12924|
# |         Amazon Home|  21666|
# |Industrial & Scie...|   2189|
# |Health & Personal...|   6886|
# |Cell Phones & Acc...|    407|
# +--------------------+-------+
# only showing top 20 rows

# %%
rddf = ndf.rdd.map(lambda row: (row['main_cat'], row))
# rddf.rdd.map(lambda row: unpackArray(row['Values'],np.float16))
rddf.collect()
# data=rddf.rdd.map(lambda row: unpackArray(row['Values'],np.float16))
# Out:
# [('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B001ED9KC6', brand='Disney', category=['Clothing, Shoes & Jewelry', 'Girls', 'Jewelry', 'Brooches & Pins'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B001ED9KC6</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB001ED9KC6">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B001ED9KC6&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B001ED9KC6/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B001ED9KC6/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      2 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#189,437 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#6482</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147442011/ref=pd_zg_hrsr_fashion_1_2">Girls</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/3880961/ref=pd_zg_hrsr_fashion_1_3">Jewelry</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/3881551/ref=pd_zg_hrsr_fashion_1_4_last">Brooches & Pins</a></b></span>\n    </li>\n</ul>\n\n</li>\n\n  \n  \n  \n  \n\n\n\n\n\n\n\n<strong>Product Warranty:</strong> For warranty information about this product, please <a href="/gp/feature.html/ref=dp_warranty_request_3P?ie=UTF8&amp;docId=1002406021" target="_blank">click here</a>\n\n\n\n\n\n\n\n\n\n\n\n\t\t\n\t\n\t\t\n\t\n\t\t\n\t\n\t\t\t\n\t\t\t\n\t\t\t\n     \t    \n            \n            \n            \n            \n            \n            <P><div class="bucket">    <script>\n    P.now("A","tellMeMoreLinkData").execute(function(A,tellMeMoreLinkData){\n        if(typeof tellMeMoreLinkData !== \'undefined\'){\n            A.state(\'lowerPricePopoverData\',{"trigger":"ns_W04ZDZWNGJEVQC9NXKAP_9902_1_hmd_pricing_feedback_trigger_product-detail","destination":"/gp/pdp/pf/pricingFeedbackForm.html/ref=_pfdpb?ie=UTF8&%2AVersion%2A=1&%2Aentries%2A=0&ASIN=B001ED9KC6&PREFIX=ns_W04ZDZWNGJEVQC9NXKAP_9902_2_&WDG=entmnt_collectibles_display_on_website&dpRequestId=W04ZDZWNGJEVQC9NXKAP&from=product-detail&storeI ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B006559Z2S', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Accessories'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 3.2 ounces</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B006559Z2S</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB006559Z2S">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B006559Z2S&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B006559Z2S/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B006559Z2S/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      2 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#25,722 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#5760</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492612011/ref=pd_zg_hrsr_fashion_1_7_last">Accessories</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#12951</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fashion_2_2">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/1265851011/ref=pd_zg_hrsr_fashion_2_3">Clothing</a> &gt; ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B006559HVM', brand='International Military Antiques, Inc.', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Accessories'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 1 pounds</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B006559HVM</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB006559HVM">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B006559HVM&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B006559HVM/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B006559HVM/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      1 customer review\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#160,677 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#11831</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492612011/ref=pd_zg_hrsr_fashion_1_7_last">Accessories</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#27921</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fashion_2_2">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/1265851011/ref=pd_zg_hr ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B00655AH2A', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Accessories', 'Belts'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 12 ounces</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B00655AH2A</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB00655AH2A">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B00655AH2A&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B00655AH2A/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B00655AH2A/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      1 customer review\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#268,065 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#48353</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2474937011/ref=pd_zg_hrsr_fashion_1_3">Accessories</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2474947011/ref=pd_zg_hrsr_fashion_1_4_last">Belts</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#8440833</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_2_2">Men</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_2_3_last">Shops</a></b></span>\n    </li>\n</ul>\n\n</li>\n\n  \n  \n  \n  \n\n\n\n\n\n\n\n<strong>Product Warranty:</strong> For warranty information about this product, please <a href="/gp/feature.html/ref=dp_warranty_request_3P?ie=UTF8&amp;docId=1002406021" target="_blank">click here</a>\n\n\n\n\n\n\n\n\n\n\n\n\t\t\n\t\n\t\t\n\t\n\t\t\n\t\n\t\t\t\n\t\t\t\n\t\t\t\n     \t    \n            \n            \n            \n            \n            \n            <P><di ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B00655AWIO', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Accessories'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 1 pounds</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B00655AWIO</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB00655AWIO">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B00655AWIO&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B00655AWIO/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B00655AWIO/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      1 customer review\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#148,308 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#11576</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492612011/ref=pd_zg_hrsr_fashion_1_7_last">Accessories</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#27181</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fashion_2_2">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/1265851011/ref=pd_zg_hrsr_fashion_2_3">Clothing</a> &gt;  ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B00655BLTI', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Accessories'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 4.8 ounces</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B00655BLTI</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB00655BLTI">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B00655BLTI&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B00655BLTI/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B00655BLTI/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      2 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#43,549 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#8038</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492612011/ref=pd_zg_hrsr_fashion_1_7_last">Accessories</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#18388</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fashion_2_2">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/1265851011/ref=pd_zg_hrsr_fashion_2_3">Clothing</a> &gt; ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=['B00FLRKXYA', 'B00MTNVEVK', 'B06Y61ZHPB', 'B0047D40OS', 'B07962T1CR', 'B07FY1VFLM', 'B00S0YA5GM', 'B018MSRAZY', 'B00PQ2AXMC', 'B004662WA0', 'B00PWOQ1M0', 'B07FCV9NZ7', 'B076GWT53G', 'B000B74XZ0', 'B07K1V9DTG', 'B00D1AJVHY', 'B07CP3GBWH', 'B075SWFJLT', 'B008WP8KN4', 'B07KNSFDB1', 'B076ZT7VMP', 'B076FNT4B6', 'B074RBN864', 'B071HP2KXG', 'B00CY9CVSO', 'B07BZR4L99', 'B07KRTZ3PF', 'B00655BPIK', 'B074DVQ4HD', 'B075Y58DVV', 'B01F8KRC70', 'B001AQ2R7C', 'B07F65BC5R', 'B003YXZ6VI', 'B079M32QC4', 'B017C8WD8Y', 'B07F2PVNKH', 'B07BK27T3Y', 'B01KJB57SE', 'B01B1VF8CQ', 'B06ZZF94NL', 'B06XYKTZ58', 'B077ZSN42Q', 'B07BWGKMZP', 'B01LDZWX46', 'B018WO16T4', 'B01F8KR5QI', 'B0091CC1OG', 'B01AZB9ML6', 'B01C32E7D8', 'B01N58XPIS', 'B00PGJ974K', 'B01LE04OXI', 'B074NB35LZ', 'B078ZW31W8'], asin='B00655C4JO', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Accessories', 'Hats & Caps', 'Balaclavas'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 4 ounces (<a href="/gp/help/seller/shipping.html/ref=dp_pd_shipping?ie=UTF8&amp;asin=B00655C4JO&amp;seller=A3I3BE71TORY04">View shipping rates and policies</a>)</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B00655C4JO</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB00655C4JO">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B00655C4JO&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B00655C4JO/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-4"><span class="a-icon-alt">3.9 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B00655C4JO/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      4 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#895 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#617</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2474937011/ref=pd_zg_hrsr_fashion_1_3">Accessories</a> & ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=None, asin='B00655DFVK', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Accessories'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 4.8 ounces</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B00655DFVK</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB00655DFVK">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B00655DFVK&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B00655DFVK/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B00655DFVK/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      2 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#34,348 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#6980</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492612011/ref=pd_zg_hrsr_fashion_1_7_last">Accessories</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#15852</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fashion_2_2">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/1265851011/ref=pd_zg_hrsr_fashion_2_3">Clothing</a> &gt; ...
#  ('Entertainment',
#   Row(also_buy=['B01N00Y5KG'], also_view=None, asin='B0091JL82K', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Outerwear'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 7 pounds (<a href="/gp/help/seller/shipping.html/ref=dp_pd_shipping?ie=UTF8&amp;asin=B0091JL82K&amp;seller=A3I3BE71TORY04">View shipping rates and policies</a>)</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B0091JL82K</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB0091JL82K">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B0091JL82K&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B0091JL82K/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">4.8 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B0091JL82K/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      8 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#3,214 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#433</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/2492606011/ref=pd_zg_hrsr_fashion_1_6">Military</a> &gt; <b><a href="https://www.amazon.com/gp/bestsellers/fashion/2492611011/ref=pd_zg_hrsr_fashion_1_7_last">Outerwear</a></b></span>\n    </li>\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#4307</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_2_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7586144011/ref=pd_zg_hrsr_fash ...
#  ('Entertainment',
#   Row(also_buy=None, also_view=['B07G8GG53P', 'B005OZ44R6', 'B0036HJGMW', 'B0111FPBHY', 'B0077RDVFU', 'B00NMKL8KG', 'B0773NVBCR', 'B00FM0BJB2', 'B01196JFHM', 'B07MHHCVQR', 'B00EEALMF4', 'B01N584ZAJ', 'B00PV3ET4Y', 'B014VFTAHS', 'B0088UQV9S', 'B00UVPS1ZA', 'B019JJF0VQ', 'B07H1PP2M2', 'B01F7NVCWO', 'B01FQHH5X6', 'B07GXN2NT6', 'B01C87EBD4', 'B00DCJPFNS', 'B074KLKCLJ', 'B015BD0T3S', 'B01MRIBYKU', 'B019E57X56', 'B00S9NT7LI', 'B07H54GYBH', 'B00P40SAJY', 'B06XGDBCLK', 'B07HVV5G8W', 'B07HH2VZK7', 'B07BSQQZHN', 'B00JHMEQUC', 'B018MUUHYS', 'B0019N0W7S', 'B00UABSQFA', 'B01AZB9ML6'], asin='B0091JL7P8', brand='IMA', category=['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military', 'Outerwear'], date=None, description=None, details='\n  <div class="content">\n\n\n\n\n\n\n\n<ul>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                                                \n\n\n\n\n\n\n\n\n\n\n<li><b>Shipping Weight:</b> 7 pounds (<a href="/gp/help/seller/shipping.html/ref=dp_pd_shipping?ie=UTF8&amp;asin=B0091JL7P8&amp;seller=A3I3BE71TORY04">View shipping rates and policies</a>)</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n<li><b>ASIN:</b> B0091JL7P8</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li><b>Average Customer Review:</b> \n\n\n\n\n<span class="dpProductDetailB0091JL7P8">\n  <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;closeButton&quot;:&quot;false&quot;,&quot;max-width&quot;:&quot;700&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_dpproductdetail_popover?ie=UTF8&amp;asin=B0091JL7P8&amp;contextId=dpProductDetail&amp;ref=acr_dpproductdetail_popover&quot;}">\n    <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n      <a class="a-link-normal a-text-normal" href="https://www.amazon.com/product-reviews/B0091JL7P8/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n        <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">4.6 out of 5 stars</span></i>\n      </a>\n    <i class="a-icon a-icon-popover"></i></a>\n  </span>\n  <span class="a-letter-space"></span>\n  <span class="a-size-small">\n    <a class="a-link-normal" href="https://www.amazon.com/product-reviews/B0091JL7P8/ref=acr_dpproductdetail_text?ie=UTF8&showViewpoints=1">\n      4 customer reviews\n    </a>\n  </span>\n</span>\n\n\n\n\n\n\n\n\n\n\n</li>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<li id="SalesRank">\n<b>Amazon Best Sellers Rank:</b> \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n#8,327 in Entertainment Collectibles (<a href="https://www.amazon.com/gp/bestsellers/entertainment-collectibles/ref=pd_dp_ts_entertainment-collectibles_1">See Top 100 in Entertainment Collectibles</a>)\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style type="text/css">\n.zg_hrsr { margin: 0; padding: 0; list-style-type: none; }\n.zg_hrsr_item { margin: 0 0 0 10px; }\n.zg_hrsr_rank { display: inline-block; width: 80px; text-align: right; }\n</style>\n\n<ul class="zg_hrsr">\n    <li class="zg_hrsr_item">\n    <span class="zg_hrsr_rank">#701</span>\n    <span class="zg_hrsr_ladder">in&nbsp;<a href="https://www.amazon.com/gp/bestsellers/fashion/ref=pd_zg_hrsr_fashion_1_1">Clothing, Shoes & Jewelry</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7147441011/ref=pd_zg_hrsr_fashion_1_2">Men</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581669011/ref=pd_zg_hrsr_fashion_1_3">Shops</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7581682011/ref=pd_zg_hrsr_fashion_1_4">Uniforms, Work & Safety</a> &gt; <a href="https://www.amazon.com/gp/bestsellers/fashion/7606661011/ref=pd_zg_hrsr_fashion_1_5">Clothing</a> &gt; <a href="https://www.amazon.com/gp/be ...

# %%
sorted(mdf.groupBy(mdf.asin).count().collect())
mdf.asin
UnDef=np.array(rdd0.map(lambda row:sum(np.isnan(row))).sample(False,0.01).collect())
    flat=rdd0.flatMap(lambda v:list(v)).filter(lambda x: not np.isnan(x)).cache()
    count,S1,S2=flat.map(lambda x: np.float64([1,x,x**2]))\
                  .reduce(lambda x,y: x+y)
# Out:
# Column<b'asin'>

# %%
filename=DATA_DIR+'/category/'+'/%s.parquet'%'Entertainment'
df_in=sqlContext.read.parquet(filename)
df_in.show()
# Out:
# +--------------------+
# |            main_cat|
# +--------------------+
# |Portable Audio & ...|
# |Cell Phones & Acc...|
# |Tools & Home Impr...|
# |Industrial & Scie...|
# |Health & Personal...|
# |Arts, Crafts & Se...|
# |Home Audio & Theater|
# | Musical Instruments|
# |   Collectible Coins|
# |   Sports & Outdoors|
# |    GPS & Navigation|
# |     Car Electronics|
# |     Office Products|
# |     All Electronics|
# |      Amazon Devices|
# |      Camera & Photo|
# |       Entertainment|
# |       Luxury Beauty|
# |        Pet Supplies|
# |                null|
# +--------------------+
# only showing top 20 rows

# %%
for meas in measurements:
    t=time()
    Query="SELECT * FROM reviews\n\tWHERE measurement = '%s'"%(meas)
    mdf = sqlContext.sql(Query)
    print(meas,': shape of mdf is ',mdf.count())

# %%
from numpy import linalg as LA
import numpy as np

from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from time import time

def computeStatistics(sqlContext,df):
    """Compute all of the statistics for a given dataframe
    Input: sqlContext: to perform SQL queries
            df: dataframe with the fields 
            Station(string), Measurement(string), Year(integer), Values (byteArray with 365 float16 numbers)
    returns: STAT, a dictionary of dictionaries. First key is measurement, 
             second keys described in computeStats.STAT_Descriptions
    """

    sqlContext.registerDataFrameAsTable(df,'weather')
    STAT={}  # dictionary storing the statistics for each measurement
    measurements=['TMAX', 'SNOW', 'SNWD', 'TMIN', 'PRCP', 'TOBS']
    
    for meas in measurements:
        t=time()
        Query="SELECT * FROM weather\n\tWHERE measurement = '%s'"%(meas)
        mdf = sqlContext.sql(Query)
        print(meas,': shape of mdf is ',mdf.count())

        data=mdf.rdd.map(lambda row: unpackArray(row['Values'],np.float16))

        #Compute basic statistics
        STAT[meas]=computeOverAllDist(data)   # Compute the statistics 

        # compute covariance matrix
        OUT=computeCov(data)

        #find PCA decomposition
        eigval,eigvec=LA.eig(OUT['Cov'])

        # collect all of the statistics in STAT[meas]
        STAT[meas]['eigval']=eigval
        STAT[meas]['eigvec']=eigvec
        STAT[meas].update(OUT)

        print('time for',meas,'is',time()-t)
    
    return STAT

# Compute the overall distribution of values and the distribution of the number of nan per year
def find_percentiles(SortedVals,percentile):
    L=int(len(SortedVals)/percentile)
    return SortedVals[L],SortedVals[-L]
  
def computeOverAllDist(rdd0):
    UnDef=np.array(rdd0.map(lambda row:sum(np.isnan(row))).sample(False,0.01).collect())
    flat=rdd0.flatMap(lambda v:list(v)).filter(lambda x: not np.isnan(x)).cache()
    count,S1,S2=flat.map(lambda x: np.float64([1,x,x**2]))\
                  .reduce(lambda x,y: x+y)
    mean=S1/count
    std=np.sqrt(S2/count-mean**2)
    Vals=flat.sample(False,0.0001).collect()
    SortedVals=np.array(sorted(Vals))
    low100,high100=find_percentiles(SortedVals,100)
    low1000,high1000=find_percentiles(SortedVals,1000)
    return {'UnDef':UnDef,\
          'mean':mean,\
          'std':std,\
          'SortedVals':SortedVals,\
          'low100':low100,\
          'high100':high100,\
          'low1000':low100,\
          'high1000':high1000
          }

# description of data returned by computeOverAllDist
STAT_Descriptions=[
('SortedVals', 'Sample of values', 'vector whose length varies between measurements'),
 ('UnDef', 'sample of number of undefs per row', 'vector whose length varies between measurements'),
 ('mean', 'mean value', ()),
 ('std', 'std', ()),
 ('low100', 'bottom 1%', ()),
 ('high100', 'top 1%', ()),
 ('low1000', 'bottom 0.1%', ()),
 ('high1000', 'top 0.1%', ()),
 ('E', 'Sum of values per day', (365,)),
 ('NE', 'count of values per day', (365,)),
 ('Mean', 'E/NE', (365,)),
 ('O', 'Sum of outer products', (365, 365)),
 ('NO', 'counts for outer products', (365, 365)),
 ('Cov', 'O/NO', (365, 365)),
 ('Var', 'The variance per day = diagonal of Cov', (365,)),
 ('eigval', 'PCA eigen-values', (365,)),
 ('eigvec', 'PCA eigen-vectors', (365, 365))
]

# %%
df['datetime'] = df['unixReviewTime'].map(lambda x: datetime.fromtimestamp(x))
df['year'] = df['datetime'].map(lambda x: x.year)
df['month'] = df['datetime'].map(lambda x: x.month)
df['day'] = df['datetime'].map(lambda x: x.day)
df['hour'] = df['datetime'].map(lambda x: x.hour)

# %%
df.year.value_counts(sort=False).plot.bar()

# %%
# df.year.value_counts(sort=False).plot.bar()
df.groupby(['year', 'month', 'day', 'hour'])['unixReviewTime'].count().plot.bar()

# %%
# df_with_image = df[df['image'].isnull() == False]
df_with_image['image'].iloc[2]
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/61rgkgvCFZL._SY88.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/61W4CUrvGGL._SY88.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/71m0NT81YnL._SY88.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/71fOeEfN8dL._SY88.jpg']

# %%
# ./MyMediaLite/bin/rating_prediction --recommender=BiasedMatrixFactorization --training-file=./data/Clothing_Shoes_and_Jewelry.csv --test-ratio=0.1

# ./MyMediaLite/bin/
# ./rating_prediction --training-file=../../data/Clothing_Shoes_and_Jewelry.csv --recommender=BiasedMatrixFactorization --test-ratio=0.1

# ./mymedialite/bin/rating_prediction --training-file="../../data/Clothing_Shoes_and_Jewelry.csv" --recommender=BiasedMatrixFactorization --test-ratio=0.1
# ./mymedialite/bin/rating_prediction --training-file="../../data/Clothing_Shoes_and_Jewelry.csv" --recommender=BiasedMatrixFactorization

# %%
from neo4j import GraphDatabase

host = "bolt://localhost:11007" # replace this with your Sandbox host
password = "password" # replace this with your Sandbox password

driver = GraphDatabase.driver(host, auth=("neo4j", "password"))
